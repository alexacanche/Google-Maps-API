# %% [markdown]
# <center> <h1> Google Maps API </h> </center>
# <center> <h3> Data Preprocessing </h> </center>

# %% [markdown]
# A. Use the [*Nearby Seach*](https://developers.google.com/places/web-service/search) Method to find all the restaurant near to the UPY (20.988459, -89.736768) around 2km. In order to fulfill this item you need to:
# * Create a *search_nearby_places* function with the appropiate parameters. It must return a JSON with the results. Places must be ranked by distance.
# * Create a table with the following columns: Name, Place Id, Rating, Place Types, Total of User Ratings.

# %%
import pandas as pd
import requests
import json

# %%
def search_nearby_places(latitude, longitude, radius, types, key):
    """
    Function to search naer places 
    according to the parameters.

    Parameters:
    latitude: float (latitude from the places we are searching by)
    longitude: float (longitude from the places we are searching by)
    radius: float (distance in meters within which to return place results)
    types: the kind of place we are lookinf for (e.g. restaurant)
    key: the API key
    
    Returns:
    A json
    """
    url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}'.format(latitude, longitude, radius, types, key)
    res = requests.get(url) #Do the request of the data and getting it 
    results = json.loads(res.content) #Reading the object into readable dictionary
    return results

# %%
#Assigning the API to a varible to better use
key = '' 

#Calling the function to a variable and writing the arguments
UPY_restaurants = search_nearby_places(20.988459,-89.736768,2000, 'restaurant', key) 

UPY_restaurants
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 20.9943362,
#      'lng': -89.72616219999999},
#     'viewport': {'northeast': {'lat': 20.99568418029151,
#       'lng': -89.72480971970849},
#      'southwest': {'lat': 20.9929862197085, 'lng': -89.72750768029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '51215063e260371f31be9c48b4b35f276677d8df',
#    'name': 'La Glorieta (Cocina y Pizzería)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112470977400009114281/photos">Óscar Albornoz</a>'],
#      'photo_reference': 'CmRaAAAAEiIXDrhSBzK6p1n5AUawo1oeP5Wbly-vsxh1t9xfYKHeVcp2Sm2tJMd22WqbZpHK2RW2gb_PyqXojlc6OIeWLBg7hteJ2FmRPcI-OBeNaPs_yIIa4trQLnT8vHy_c2hgEhC2-X3DRagGfRezeCP3vXYkGhQq6LVLBXDyoWRyD85uXmfL8J8cLg',
#      'width': 3024}],
#    'place_id': 'ChIJC9i7XEsNVo8Ro2-sdS45rBg',
#    'plus_code': {'compound_code': 'X7VF+PG Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7VF+PG'},
#    'rating': 4.1,
#    'reference': 'ChIJC9i7XEsNVo8Ro2-sdS45rBg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Mérida'},
#   {'geometry': {'location': {'lat': 20.9892802, 'lng': -89.7235666},
#     'viewport': {'northeast': {'lat': 20.9905874802915,
#       'lng': -89.7222163197085},
#      'southwest': {'lat': 20.9878895197085, 'lng': -89.7249142802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0c95338760a6b57abb8c90f793757973d37a3858',
#    'name': 'Mr. Cazuelas',
#    'place_id': 'ChIJ3WHHeJkMVo8RO_z2pfoDFZg',
#    'plus_code': {'compound_code': 'X7QG+PH Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7QG+PH'},
#    'rating': 4,
#    'reference': 'ChIJ3WHHeJkMVo8RO_z2pfoDFZg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Calle 89, Caucel'},
#   {'geometry': {'location': {'lat': 20.993318, 'lng': -89.72394469999999},
#     'viewport': {'northeast': {'lat': 20.9947245302915,
#       'lng': -89.72259806970848},
#      'southwest': {'lat': 20.9920265697085, 'lng': -89.72529603029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '30608abf06a3d55762f3cf88c6ebfb59e6600755',
#    'name': 'El Rincón Del Tabas',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100844704817294711241/photos">Victor Suarez</a>'],
#      'photo_reference': 'CmRaAAAAxevdM6w50OXKgYAHsf7TCOJLu-LuzHJhrOT5xP1-UQz6kp8EyyajQXGgQ2KCBUUWFOlRF1_wPAiJbI0pUOEnj1RTG_-7vtkPZ0u1sCIvTTN09ebbW0aw5GyI1eexTM8jEhCwN_uEv867taM5SulQ7tsFGhQGdHhl-Gg5YtJA3XjzO6tQ4HcUnQ',
#      'width': 4000}],
#    'place_id': 'ChIJn4UFHpwMVo8RZOfFHQCuIwo',
#    'plus_code': {'compound_code': 'X7VG+8C Mérida Municipality, Yucatan, Mexico',
#     'global_code': '76GGX7VG+8C'},
#    'rating': 5,
#    'reference': 'ChIJn4UFHpwMVo8RZOfFHQCuIwo',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Calle 77-A 77'},
#   {'geometry': {'location': {'lat': 20.9935837, 'lng': -89.7235008},
#     'viewport': {'northeast': {'lat': 20.9951064302915,
#       'lng': -89.7221607697085},
#      'southwest': {'lat': 20.9924084697085, 'lng': -89.7248587302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4084cb111246633c21ff68a31c522f01099d8f27',
#    'name': 'Moyoyos burger',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111027710432853138137/photos">Moyoyos Kennels</a>'],
#      'photo_reference': 'CmRaAAAA5OEjrfw6L-VQ6wK7EPfpXPxq4KS-5z6J7DQ8wcsjoBW_0Gq1HMD01_EFfaLmUBKMwN7QaorSMSgF3lqeeP9uzljBBRsa2XfN68WjJYxyMzD8iRAY6Lz_4MWHQjIqgAzFEhAMQK0rOLf51cOYdP2e31rWGhS78742Igp2a-hyHrYcFW-71N_sLA',
#      'width': 1080}],
#    'place_id': 'ChIJqxQ91h0NVo8R52sc8a1HlvE',
#    'plus_code': {'compound_code': 'X7VG+CH Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7VG+CH'},
#    'reference': 'ChIJqxQ91h0NVo8R52sc8a1HlvE',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 77 800'},
#   {'geometry': {'location': {'lat': 20.9887511, 'lng': -89.72230379999999},
#     'viewport': {'northeast': {'lat': 20.9900881302915,
#       'lng': -89.7209540197085},
#      'southwest': {'lat': 20.98739016970849, 'lng': -89.7236519802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '752346a25e2f154673bf82a953e3efba988575a4',
#    'name': 'Cocina economica "El sabor de doña antonia"',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 363,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117281795601236564539/photos">Asucena Pech</a>'],
#      'photo_reference': 'CmRaAAAAwwwyGf0LJpeDYKDkry5S-PAqirtKkQGlTjQtNV_TnFyx3Rcnq4rVChhwsTU2TIvw_QOZTFEmhw2Z1Tbug8k3OVhmtddU6JUdpiuNEvYOVR5ftJqWmZCaX4jSekF7aYCREhDGRhi7c09hz82BHB0plrNoGhQCz2pAPtXyWa8qqFFQwqOriXjszQ',
#      'width': 640}],
#    'place_id': 'ChIJaQJm928NVo8RAN8mnDmvYEk',
#    'plus_code': {'compound_code': 'X7QH+G3 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7QH+G3'},
#    'reference': 'ChIJaQJm928NVo8RAN8mnDmvYEk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 91 97314 Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 20.9973152, 'lng': -89.7256647},
#     'viewport': {'northeast': {'lat': 20.9986653802915,
#       'lng': -89.72428056970848},
#      'southwest': {'lat': 20.9959674197085, 'lng': -89.72697853029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '94a25dcf077a6066604267e21c4d8d35b2d77ce9',
#    'name': 'Cemitas Poblanas Doña Dulce',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107050260111115920816/photos">Jose Rios</a>'],
#      'photo_reference': 'CmRaAAAAG5DXj42vbZPOWrKTXWqSQG_c-oGU51lReZfm_eFtq5JVl9WlMRP_yj-5CLsaC_WAcd-mwSVGQDOpSxtxOBdmqGq8f9H1Fku8Ak2T2m7ClF8D6zoSAQRkF1HqduNUizawEhBR3MKRfQ4bZH3q5dVFsZ9yGhTFP9p2-WPHA0mHxdH6G1bczmMmoA',
#      'width': 1920}],
#    'place_id': 'ChIJ-18misANVo8R8_gP-uVUAMY',
#    'plus_code': {'compound_code': 'X7WF+WP Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7WF+WP'},
#    'rating': 4.8,
#    'reference': 'ChIJ-18misANVo8R8_gP-uVUAMY',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 22,
#    'vicinity': 'calle 112b x 67 y 67a los almendros, 97314, Mérida'},
#   {'geometry': {'location': {'lat': 20.9975307, 'lng': -89.7256029},
#     'viewport': {'northeast': {'lat': 20.99887853029151,
#       'lng': -89.72428761970848},
#      'southwest': {'lat': 20.9961805697085, 'lng': -89.7269855802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'e22b717561fbd87a9fbd561e7e92ce6ac9c2ae92',
#    'name': 'Hamburguesas Maaaa de la 112.',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 750,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118028157930418523984/photos">Yoshua Gonzalez</a>'],
#      'photo_reference': 'CmRaAAAA-3V89YpU4zBWxrkyFypCiiHS_Oa6YW1fIyPl_gasPD2x0J5PvNw4rBP0dMCkvEJIBxKcHSAPdY_C6Aq1E78XHSJOFmBKQY7OC_-RXHHriXfQlCYdB13mwrF7abNOhuYoEhAPeYe9Jhbr2Nql8rRr6kjuGhSrhpK_ES-motyCSf7aGoIRhSRIPA',
#      'width': 750}],
#    'place_id': 'ChIJXTh3gaoNVo8RovFdjQ-lN10',
#    'plus_code': {'compound_code': 'X7XF+2Q Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XF+2Q'},
#    'rating': 3.7,
#    'reference': 'ChIJXTh3gaoNVo8RovFdjQ-lN10',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Calle 112B'},
#   {'geometry': {'location': {'lat': 20.996515, 'lng': -89.72460749999999},
#     'viewport': {'northeast': {'lat': 20.9978002802915,
#       'lng': -89.7232555697085},
#      'southwest': {'lat': 20.9951023197085, 'lng': -89.7259535302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '20ae18c28bf7f1ac4b157bfa6f829e1147a42629',
#    'name': 'Carnívoros',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103470461646416855876/photos">eduardo rincon gamboa</a>'],
#      'photo_reference': 'CmRaAAAAQ05O6zFIQsmVvGNa9LlnsXADKGMDcr1D5FHe5j8Ca-XD_TgP5N5kJbV_gF7h1wsNnswFhEj7T_Xzer_8aZa4zqivm6CB6-bHedhFekNy_w5ZMOLoA6vtQyFUf4EbtN4CEhCvjtroijnt8sUs56TlvTnmGhTQPZT-H4lqnU3cg32Rf53h_u6nfw',
#      'width': 5312}],
#    'place_id': 'ChIJx9nxwp0MVo8RvujKFHXH6H4',
#    'plus_code': {'compound_code': 'X7WG+J5 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7WG+J5'},
#    'rating': 4.2,
#    'reference': 'ChIJx9nxwp0MVo8RvujKFHXH6H4',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 40,
#    'vicinity': 'Calle 69 97314, Ciudad Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 20.99656909999999,
#      'lng': -89.72424629999999},
#     'viewport': {'northeast': {'lat': 20.9978341802915,
#       'lng': -89.7228937197085},
#      'southwest': {'lat': 20.9951362197085, 'lng': -89.7255916802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '60ed2c5d1a4c991c3ad222d17aa16f58e6a3caf1',
#    'name': 'Modelorama',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJozhU3J0MVo8RKZTNG5qZyu4',
#    'plus_code': {'compound_code': 'X7WG+J8 Mérida Municipality, Yucatan, Mexico',
#     'global_code': '76GGX7WG+J8'},
#    'rating': 4.8,
#    'reference': 'ChIJozhU3J0MVo8RKZTNG5qZyu4',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'bar',
#     'liquor_store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Calle 69 0'},
#   {'geometry': {'location': {'lat': 20.9998287, 'lng': -89.72573709999999},
#     'viewport': {'northeast': {'lat': 21.0011944302915,
#       'lng': -89.72449006970848},
#      'southwest': {'lat': 20.9984964697085, 'lng': -89.72718803029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'de3a373bd6aaf3d8cea31dd92d32dac99c827645',
#    'name': 'La BOMBA DEL SABOR',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111038143495180908056/photos">Elian Yoryet Casanueva Saldivar</a>'],
#      'photo_reference': 'CmRaAAAA56ka6eDTdzQX_R_6klTa4HYQ8jUCygqbtIdCefWIeV7g76NT2vjqsC8a7piSfB2sA0Xfs3usxKUtfVvv3ZgqCXsH7r4yC1Qd8aBMOkV0LsRv8KihPKfHnIHlIstadrKnEhADkRmwUN6ANF6KimlY3lA7GhQFf2uVZqbX8O6pZWvU5tZKNqU1OQ',
#      'width': 1080}],
#    'place_id': 'ChIJXzbguNgLVo8RnxttdBhYakc',
#    'plus_code': {'compound_code': 'X7XF+WP Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XF+WP'},
#    'rating': 5,
#    'reference': 'ChIJXzbguNgLVo8RnxttdBhYakc',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Calle 112B #713D, Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 20.996409, 'lng': -89.72260709999999},
#     'viewport': {'northeast': {'lat': 20.9977818302915,
#       'lng': -89.7212593197085},
#      'southwest': {'lat': 20.9950838697085, 'lng': -89.72395728029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'd57b0922384b5e843203b7c256c5bbaf1cfb0899',
#    'name': 'La Carlota',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108046929243728680035/photos">René Cortés</a>'],
#      'photo_reference': 'CmRaAAAADjCit6dKRuBECOVFb6Rlw_Q2b6s4Lw4fU47Do2vSqwV_JOntvl2uWtMc-M0-CAH3to2Za77OU2Mp7UCzGOs26163HGuDmyaeyTtXKZISmFDxar3Dx-CdHcNyCei8HAVwEhAU5bmBWrh_5joONuupbsDnGhSlL92CzdOiZp2b5AXE0NmfKn_YgA',
#      'width': 1280}],
#    'place_id': 'ChIJVWRJiW8NVo8R7E46087W96E',
#    'plus_code': {'compound_code': 'X7WG+HX Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7WG+HX'},
#    'rating': 5,
#    'reference': 'ChIJVWRJiW8NVo8R7E46087W96E',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Calle 69 #828, Los Almendros III, Mérida'},
#   {'geometry': {'location': {'lat': 20.99220709999999, 'lng': -89.7200615},
#     'viewport': {'northeast': {'lat': 20.9935498302915,
#       'lng': -89.7187122197085},
#      'southwest': {'lat': 20.9908518697085, 'lng': -89.7214101802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'ff7a39dbe5bb296ca8c72d5c490012a5920ca803',
#    'name': 'The witch burgers',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1223,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110507939685883191760/photos">Emmanuel Pat</a>'],
#      'photo_reference': 'CmRaAAAAFpm9S50eoK7CCbk79qyTVv-BBROzKmH7FlvMqjkFdDAv4msJFlIX_mQ3TppSPwoRCpTLOZCMkarai5_ILYKxbE17AxaN4EaIEfhq-FCM8dc_940JmnjJqO4u0FLS3kH2EhBYllJMbzSLn3CjoETgpV3AGhRcW0_Vf8NvLKmClcmtk8_pxku8wQ',
#      'width': 2167}],
#    'place_id': 'ChIJk8-rWwgNVo8RhVnpRaHabZ8',
#    'plus_code': {'compound_code': 'X7RH+VX Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7RH+VX'},
#    'rating': 5,
#    'reference': 'ChIJk8-rWwgNVo8RhVnpRaHabZ8',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '#803, Calle 77D, Mérida'},
#   {'geometry': {'location': {'lat': 20.9995933, 'lng': -89.7241751},
#     'viewport': {'northeast': {'lat': 21.0010242302915,
#       'lng': -89.72280956970849},
#      'southwest': {'lat': 20.9983262697085, 'lng': -89.7255075302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '09919e36d2c0a0c677b4d17b76c81f4e9880cfe6',
#    'name': 'Panuchos & Salbutes El Almendrito',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 578,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118354559545815287588/photos">Alberto Farfán</a>'],
#      'photo_reference': 'CmRaAAAATYXyUthEM-oAIT4RtoSobifOpqUyN97ABadu4WRCf6msfcDgquO8uu9A40V5V4mHrnRCQaFW9uOEGqDe97vs-6-g92tci8gmmGcDvElt7GkAr1gKDKfVoHUUSVczJg5qEhBpvCF8dVmLolXqNeu0SiLBGhTM4YIB_90C0RJQCS9O2RJcBHdPBQ',
#      'width': 763}],
#    'place_id': 'ChIJ80ttQuMLVo8RC-oH1Eisi8A',
#    'plus_code': {'compound_code': 'X7XG+R8 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XG+R8'},
#    'rating': 5,
#    'reference': 'ChIJ80ttQuMLVo8RC-oH1Eisi8A',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Calle 61 910B'},
#   {'geometry': {'location': {'lat': 20.9986447, 'lng': -89.7230403},
#     'viewport': {'northeast': {'lat': 20.9999780802915,
#       'lng': -89.7216942697085},
#      'southwest': {'lat': 20.9972801197085, 'lng': -89.7243922302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '6d12df97d6b931d3b914a2a7cc046a2d8ded7bbc',
#    'name': 'HAMBURGUESAS HARAMYYU BIRIZ',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJHdPcMX0LVo8RhSB1GURFT7U',
#    'plus_code': {'compound_code': 'X7XG+FQ Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XG+FQ'},
#    'reference': 'ChIJHdPcMX0LVo8RhSB1GURFT7U',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 65 905, Ciudad Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 21.0008062, 'lng': -89.7234368},
#     'viewport': {'northeast': {'lat': 21.0022281302915,
#       'lng': -89.7220739697085},
#      'southwest': {'lat': 20.9995301697085, 'lng': -89.72477193029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '8ee8315cd353bbd3b739792631df0ea0e28f913a',
#    'name': 'PerryBurguer',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117293953942763458122/photos">Antonio Hernandez chac</a>'],
#      'photo_reference': 'CmRZAAAA0sAmbcXeuwjA2V8TPOhOAhKQdDxnolKyDCHY2lN_IaSezGrBqVbG3JcNHIw84s7S_FizO1zj7k0Ar7j0zDna9bKugwXFJn2k_biMd0OPvDneAbRi8UohngMomnpq1bkUEhCzj7yINBJDimMNgviQC4kGGhTEuk-bYEqz5Nf-Tggk-Vp6qJMwZw',
#      'width': 4160}],
#    'place_id': 'ChIJldA29UgLVo8Rj6HAXz7I2iM',
#    'plus_code': {'compound_code': '272G+8J Mérida, Yucatan, Mexico',
#     'global_code': '76HG272G+8J'},
#    'rating': 4.5,
#    'reference': 'ChIJldA29UgLVo8Rj6HAXz7I2iM',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Unnamed Road, 97314'}],
#  'status': 'OK'}

# %%
#Create again a json, take the objects of UPY_restaurants['results'] to string and order them in columns
table_UPY = pd.read_json(json.dumps(UPY_restaurants['results']), orient='columns')

#Selecting only the 'name', 'id', 'rating', 'types', 'user_ratings_total' columns
table_UPY = table_UPY[['name', 'id', 'rating', 'types', 'user_ratings_total']]

#Renaming the columns 
table_UPY = table_UPY.rename(columns={"name" : "Name", "id" : "Place Id", "rating" : "Rating", "types" : "Place Types", "user_ratings_total" : "Total of User Ratings"})

table_UPY
# Out:
#                                            Name  \
# 0               La Glorieta (Cocina y Pizzería)
# 1                                  Mr. Cazuelas
# 2                           El Rincón Del Tabas
# 3                                Moyoyos burger
# 4   Cocina economica "El sabor de doña antonia"
# 5                   Cemitas Poblanas Doña Dulce
# 6                 Hamburguesas Maaaa de la 112.
# 7                                    Carnívoros
# 8                                    Modelorama
# 9                            La BOMBA DEL SABOR
# 10                                   La Carlota
# 11                            The witch burgers
# 12            Panuchos & Salbutes El Almendrito
# 13                  HAMBURGUESAS HARAMYYU BIRIZ
# 14                                 PerryBurguer
#
#                                     Place Id  Rating  \
# 0   51215063e260371f31be9c48b4b35f276677d8df     4.1
# 1   0c95338760a6b57abb8c90f793757973d37a3858     4.0
# 2   30608abf06a3d55762f3cf88c6ebfb59e6600755     5.0
# 3   4084cb111246633c21ff68a31c522f01099d8f27     NaN
# 4   752346a25e2f154673bf82a953e3efba988575a4     NaN
# 5   94a25dcf077a6066604267e21c4d8d35b2d77ce9     4.8
# 6   e22b717561fbd87a9fbd561e7e92ce6ac9c2ae92     3.7
# 7   20ae18c28bf7f1ac4b157bfa6f829e1147a42629     4.2
# 8   60ed2c5d1a4c991c3ad222d17aa16f58e6a3caf1     4.8
# 9   de3a373bd6aaf3d8cea31dd92d32dac99c827645     5.0
# 10  d57b0922384b5e843203b7c256c5bbaf1cfb0899     5.0
# 11  ff7a39dbe5bb296ca8c72d5c490012a5920ca803     5.0
# 12  09919e36d2c0a0c677b4d17b76c81f4e9880cfe6     5.0
# 13  6d12df97d6b931d3b914a2a7cc046a2d8ded7bbc     NaN
# 14  8ee8315cd353bbd3b739792631df0ea0e28f913a     4.5
#
#                                           Place Types  Total of User Ratings
# 0   [restaurant, food, point_of_interest, establis...                   14.0
# 1   [restaurant, food, point_of_interest, establis...                    3.0
# 2   [restaurant, food, point_of_interest, establis...                    2.0
# 3   [restaurant, food, point_of_interest, establis...                    NaN
# 4   [restaurant, food, point_of_interest, establis...                    NaN
# 5   [restaurant, food, point_of_interest, establis...                   22.0
# 6   [restaurant, food, point_of_interest, establis...                    6.0
# 7   [restaurant, food, point_of_interest, establis...                   40.0
# 8   [convenience_store, bar, liquor_store, restaur...                    4.0
# 9   [restaurant, food, point_of_interest, establis...                    2.0
# 10  [meal_delivery, restaurant, food, point_of_int...                    4.0
# 11  [restaurant, food, point_of_interest, establis...                    1.0
# 12  [restaurant, food, point_of_interest, establis...                    1.0
# 13  [restaurant, food, point_of_interest, establis...                    NaN
# 14  [restaurant, food, point_of_interest, establis...                   11.0

# %% [markdown]
# B. Create a function to Find the Place Id given Place Name (String) and Location (Lat/Lont Tuple).

# %%
def place_id(name, latitude, logitude, key):
    """
    Function to find a place given a place name and a location.

    Parameters:
    latitude: float (latitude from the places we are searching by)
    longitude: float (longitude from the places we are searching by)
    name: string (name of the places)
    key: the API key
    
    Returns:
    A string with the id
    """
    url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&inputtype={}&locationbias=point:{},{}&key={}'.format(name, 'textquery', latitude, logitude, key)
    res = requests.get(url) #Do the request of the data and getting it 
    results = json.loads(res.content) #Reading the object into readable dictionary
    results = results['candidates'][0]['place_id'] #Selecting only the id from the dictionary, from the list and again from the dictionary
    return results #A string

# %%
#Making sure it works with a test
Carnívoros_id = place_id('Carnívoros', 20.996515, -89.724, key)
Carnívoros_id
# Out:
# 'ChIJx9nxwp0MVo8RvujKFHXH6H4'

# %% [markdown]
# C. Find the Place ID of the following places using your functions:
# * McCarthy's Irish Pub - Caucel
# * Starbucks Montejo
# * Los Trompos Circuito

# %%
mccarthys_caucel = place_id("McCarthy's Irish Pub - Caucel", 20.999940, -89.682572, key)
starbucks_montejo = place_id("Starbucks Montejo",20.984971, -89.618131, key)
trompos_circuito = place_id("Los Trompos Circuito",20.984971, -89.618131, key)
print("McCarthy's Irish Pub - Caucel: {}".format(mccarthys_caucel))
print("Starbucks Montejo: {}".format(starbucks_montejo))
print("Los Trompos Circuito: {}".format(trompos_circuito))
# Out:
# McCarthy's Irish Pub - Caucel: ChIJJyKKOKB0Vo8RCQcxkUw6hp8
# Starbucks Montejo: ChIJaUUfylFxVo8RgEGjoansPbc
# Los Trompos Circuito: ChIJpVKXOq12Vo8RK4bUWILT9dI

# %% [markdown]
# D. Use the [*Place Details*](https://developers.google.com/places/web-service/details#PlaceDetailsResults) Method to find the Reviews of a Place in English and Spanish. In order to fulfill this item you need to:
# * Create a *find_reviews* function with the appropiate parameters. It must return a JSON with the results.
# * Create a table with the following columns: Author Name, Language, Rating, Text, Time.

# %%
def find_reviews(place_id, key):
    """
    Function to  find the Reviews of a Place 
    in English and Spanish given the place id.

    Parameters:
    place_id: string (the id of the place)
    key: the API key
    
    Returns:
    A json                                  
    """                   
    url = 'https://maps.googleapis.com/maps/api/place/details/json?place_id={}&language=en,es&fields=review&key={}'.format(place_id, key)
    res = requests.get(url) #Do the request of the data and getting it 
    results = json.loads(res.content) #Reading the object into readable dictionary
    return results

# %%
#Making sure it works with a test
mccarthys_caucel_reviews = find_reviews('ChIJJyKKOKB0Vo8RCQcxkUw6hp8', key)
mccarthys_caucel_reviews
# Out:
# {'html_attributions': [],
#  'result': {'reviews': [{'author_name': 'David Guillermo',
#     'author_url': 'https://www.google.com/maps/contrib/108835593422479203315/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh6.ggpht.com/-qROp1y6xMq0/AAAAAAAAAAI/AAAAAAAAAAA/xrBzWrF6AUo/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#     'rating': 3,
#     'relative_time_description': 'a month ago',
#     'text': 'They need person to regulate the sound inside the place',
#     'time': 1566612760},
#    {'author_name': 'Patrick',
#     'author_url': 'https://www.google.com/maps/contrib/110157321358354256956/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh5.ggpht.com/-IA6GV8CxUH8/AAAAAAAAAAI/AAAAAAAAAAA/B3p7A3S2beM/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'One of the best pubs around.\nGreat service, great menu, fair prices, superb music.',
#     'time': 1518688093},
#    {'author_name': 'Toni Aguilar',
#     'author_url': 'https://www.google.com/maps/contrib/103748126392715557478/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh5.ggpht.com/-NJV60otC-hE/AAAAAAAAAAI/AAAAAAAAAAA/IUxjmuO87WE/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'Rockers, music lovers in general will enjoy this place alot, good variety of beer and drinks also the food is amaizing at a good price points! Ambience is perfect and live music on stage couple days a week make it better! Go and enjoy yourself',
#     'time': 1516852970},
#    {'author_name': 'Islas',
#     'author_url': 'https://www.google.com/maps/contrib/106046994845938765413/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh4.ggpht.com/-meMgiNgJfqM/AAAAAAAAAAI/AAAAAAAAAAA/izRi6ikb7yI/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'I love this place, one of the best places to drink a good beer and listen rock music and the food is really awesome',
#     'time': 1522860496},
#    {'author_name': 'monica ravell',
#     'author_url': 'https://www.google.com/maps/contrib/117122126063276406803/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh5.ggpht.com/-7MhrgLUCsxw/AAAAAAAAAAI/AAAAAAAAAAA/VVzvMql2IEs/s128-c0x00000000-cc-rp-mo/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'Great place to listen to good rock',
#     'time': 1531876412}]},
#  'status': 'OK'}

# %%
#Creating a data frame for the find_reviews with the id of mccarthys caucel
table_find_reviews = pd.DataFrame(mccarthys_caucel_reviews['result']['reviews'])

#changing the time format
table_find_reviews['time'] = pd.to_datetime(table_find_reviews['time'],unit='s') 

#Choosing the Author Name, Language, Rating, Text, Time columns.
table_find_reviews = table_find_reviews[['author_name', 'language', 'rating', 'time', 'text']]

#Renaming the columns to Author Name, Language, Rating, Text, Time.
table_find_reviews = table_find_reviews.rename(columns={"author_name" : "Author Name", "language" : "Language", "rating" : "Rating", "text" : "Text", "time" : "Time" })

table_find_reviews
# Out:
#        Author Name Language  Rating                Time  \
# 0  David Guillermo       en       3 2019-08-24 02:12:40
# 1          Patrick       en       5 2018-02-15 09:48:13
# 2     Toni Aguilar       en       5 2018-01-25 04:02:50
# 3            Islas       en       5 2018-04-04 16:48:16
# 4    monica ravell       en       5 2018-07-18 01:13:32
#
#                                                 Text
# 0  They need person to regulate the sound inside ...
# 1  One of the best pubs around.\nGreat service, g...
# 2  Rockers, music lovers in general will enjoy th...
# 3  I love this place, one of the best places to d...
# 4                 Great place to listen to good rock

# %% [markdown]
# E. Find similar places to Los Trompos Circuito. Rank them by its "Prominence". In order to fulfill this item you need to:
# * Create a *find_similar* function with the appropiate parameters. It must return a JSON with the results.
# * Create a table with the following columns: Place Name, Place Id, Rating, Total of User Ratings.

# %%
def find_similar(latitude, longitude, radius, types, key):
    """
    Function to similar places, rank them by its prominence.

    Parameters:
    latitude: float (latitude from the places we are searching by)
    longitude: float (longitude from the places we are searching by)
    radius: float (distance in meters within which to return place results)
    types: the kind of place we are lookinf for (e.g. restaurant)
    key: the API key
    
    Returns:
    A json
    """
    url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&rankby=prominence&types={}&key={}'.format(latitude, longitude, radius, types, key)
    res = requests.get(url) #Do the request of the data and getting it 
    results = json.loads(res.content) #Reading the object into readable dictionary
    return results

# %%
trompos_circuito = find_similar(20.998694, -89.6175974, 500, 'restaurant', key)
trompos_circuito
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAADCudhpgo134McEJkuty_odR3D1DdeCPbl3yHMjIMWc1yHjzgIXlqqXDUtoXXqr_cfNzyES_IzuQUNQudxYuEPubnBCQpu2ulUUTlmIkOUQp1jxS7qpxw5d-OtBLLrR5D-h7vHkxH4NiNbuP4m4MIcYmn69QXhb7v7K_K4Pm6dYxo6LrpmwxVWBQNfvH9tTt16laxxGqR099-I-f803FZmCfQ0KmK49g_351rfgiPyZtzCJp9Ae_l4So20xEshSyft0GN53_M_QYgGpT-a4bJJ4J0_v9GVsSrjPJmhd-3sgmrCDMAIUsAOHuu9MOSf-_16fUhdptle308Tku_0xjWncOmkYZunsRxmQAXe6o6zmzTrElfP0Dt6ngGz0kv756Jl50xw-wTa_GqlXT4nHkW6cSEPPOdEi7AvRVRcaM1dG0zMsaFKfvieGvstePH-vLNdLSobQYVjxS',
#  'results': [{'geometry': {'location': {'lat': 20.99881,
#      'lng': -89.61743539999999},
#     'viewport': {'northeast': {'lat': 21.0000983802915,
#       'lng': -89.61603351970848},
#      'southwest': {'lat': 20.9974004197085, 'lng': -89.6187314802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'cf6c67c9eb44c578189fe7afa775b9c87026672f',
#    'name': 'Los Trompos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100748773694559340701/photos">TecnoMaya</a>'],
#      'photo_reference': 'CmRaAAAAUKMtQX_1GIXMIA_UuoahAn9w-RYT7r_xlnp1QJOZA6SGiDSzwgLyNth4_1N3oft9ShDNkMOS8tJPoetX8je94QQRg2fBHIOZjWGO8w22Nl-rQwGv1mJ2TCn8Rbdh6PrREhClqPDucpiC4iXt-IlCU9OsGhTue5kYWYg9mQsQ5eaY99bPlTxaLw',
#      'width': 5312}],
#    'place_id': 'ChIJpVKXOq12Vo8RK4bUWILT9dI',
#    'plus_code': {'compound_code': 'X9XM+G2 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XM+G2'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJpVKXOq12Vo8RK4bUWILT9dI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3130,
#    'vicinity': 'Calle 31 x 32 #133, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9984348, 'lng': -89.6177091},
#     'viewport': {'northeast': {'lat': 20.9998387302915,
#       'lng': -89.61637096970848},
#      'southwest': {'lat': 20.9971407697085, 'lng': -89.61906893029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0525209b56b3dfac93492825024c73986cb1c704',
#    'name': 'Mi Viejo Molino',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100105566345961373500/photos">jhonathan izquierdo</a>'],
#      'photo_reference': 'CmRaAAAAs9T5gWR1yJy7SUyrFiE-kvGYAzgk80aY7yZQzKhw_-nTxqunQv1PrGFCwnzlUezkZbV5TeJtEFfOC-oPPFFaHcdI9n24cwNbHjb34ce7S5fmFAKX-UsF1suaD3QPJR8xEhAqOOSDLCGtWT6EHLaPgLexGhSvz-kJauAA73-MwokZnqFfJwhi1w',
#      'width': 4160}],
#    'place_id': 'ChIJA2XvLq12Vo8RmHzVkbC-a1M',
#    'plus_code': {'compound_code': 'X9XJ+9W Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+9W'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJA2XvLq12Vo8RmHzVkbC-a1M',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1391,
#    'vicinity': 'Circuito Colonias 132, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9981513, 'lng': -89.6188694},
#     'viewport': {'northeast': {'lat': 20.9995989802915,
#       'lng': -89.61753946970849},
#      'southwest': {'lat': 20.99690101970849, 'lng': -89.6202374302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3da77355187a5c061f10675393003c55e6d23bad',
#    'name': 'Pizza del Perro Negro',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 576,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114062633533081902517/photos">Pizza del Perro Negro</a>'],
#      'photo_reference': 'CmRaAAAAjzWm1Vw4A0CaSFu0k6i3xKCDo2-c7FI_d-wNMxlRdfTNB-rNUDAvsbU7x_SKlzaHgn9MeiqKxA-_QsM1xVwQo7906KuF7h5wJGjth8JQglqgNQ9-3tqLNrXVwrrw7bp_EhAheaPX5y3P6hSfaAuubLJ5GhTmuEOAPmmr6kCqwTkZN13L_5r6gQ',
#      'width': 1024}],
#    'place_id': 'ChIJS67Ey6x2Vo8RTiTblDl7VT0',
#    'plus_code': {'compound_code': 'X9XJ+7F Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+7F'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJS67Ey6x2Vo8RTiTblDl7VT0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1792,
#    'vicinity': 'Circuito Colonias 138, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 21.0006563, 'lng': -89.6152867},
#     'viewport': {'northeast': {'lat': 21.00202808029151,
#       'lng': -89.61404141970849},
#      'southwest': {'lat': 20.9993301197085, 'lng': -89.61673938029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '657620905f41cddeeefd73c87f0038e76d1320b9',
#    'name': 'Mr. Pampas',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112027953135784105871/photos">lebrak silva</a>'],
#      'photo_reference': 'CmRaAAAAprecKRoQ_BpNW4IbAjTcQSmYyLee7p-LaugafgfU-7kEDEWF7joiyl2_FclCbJw5JpyrhD88LUGOrNoIkeWoGx4PPttnYrTWMmbQGDEbnEiz9UXjlBzKOS9oGDF_X0fvEhAfzP-N7-n4bg4AQqeOMR_hGhSYyNnn4AQS5--H0sxThZi5QNovJQ',
#      'width': 1920}],
#    'place_id': 'ChIJE1CvhrJ2Vo8RF6OCmqVdXjU',
#    'plus_code': {'compound_code': '292M+7V Mérida, Yucatan, Mexico',
#     'global_code': '76HG292M+7V'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJE1CvhrJ2Vo8RF6OCmqVdXjU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3935,
#    'vicinity': '118 x, Prolongación paseo Montejo, Calle 27, México, Mérida'},
#   {'geometry': {'location': {'lat': 20.9987778, 'lng': -89.61446970000001},
#     'viewport': {'northeast': {'lat': 21.0000301302915,
#       'lng': -89.6131411697085},
#      'southwest': {'lat': 20.9973321697085, 'lng': -89.6158391302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd39c4485a4687e3717417c89a18cc8e6219ff525',
#    'name': 'A la pimienta',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107000429126721375259/photos">A la pimienta</a>'],
#      'photo_reference': 'CmRaAAAACj4_zt50uR-2SAyQ-wEkajzq_hv0kGLPvcHkk9SfXTOxaQk_cjk8EXilT9e3oc0K8KKPi1VsqmGj9DGkvT_68AKfvtI4VZ6FJT8hJp8UIBEc1KRl1RnHSYQ91GrKssXsEhDJ6t0EtRC1-WB8I604YvYyGhTrPNOv7GKt-UqMDxjKLPerFISDLw',
#      'width': 1200}],
#    'place_id': 'ChIJ_7yIt7J2Vo8ROAqvR1B2Ivc',
#    'plus_code': {'compound_code': 'X9XP+G6 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XP+G6'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJ_7yIt7J2Vo8ROAqvR1B2Ivc',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 257,
#    'vicinity': 'Circuito Colonias 127, México, Mérida'},
#   {'geometry': {'location': {'lat': 20.9958321, 'lng': -89.6160525},
#     'viewport': {'northeast': {'lat': 20.9971913802915,
#       'lng': -89.61479411970849},
#      'southwest': {'lat': 20.9944934197085, 'lng': -89.6174920802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '7ace37da5f0e3d05373f8b7bfe11c29cd86105fb',
#    'name': 'Los Originales Tacos de Res',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101147416958233449587/photos">Kaa Ab S</a>'],
#      'photo_reference': 'CmRaAAAAz3jck7u1fMOScAI4aO6eEOK3ybwNAJ7b-Ghub8UwKHuSh9ANmbv8I1xQGbmtb2vAOevY6S7wAA_bRsyS7h-bETlkrHq_MsnA4GAtTwB0hsPVftyFCLdA128hn3K9RPQ6EhDxbvU6bOkVXlCw-KgNMGpNGhTBs1p4khGl8E4Yhf0kpc9QaEWOAA',
#      'width': 1080}],
#    'place_id': 'ChIJScV8m1JxVo8RGtH_DNMAHcs',
#    'plus_code': {'compound_code': 'X9WM+8H Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WM+8H'},
#    'rating': 4.5,
#    'reference': 'ChIJScV8m1JxVo8RGtH_DNMAHcs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 35,
#    'vicinity': 'Itzimná, Mérida'},
#   {'geometry': {'location': {'lat': 21.001493, 'lng': -89.61488299999999},
#     'viewport': {'northeast': {'lat': 21.0027158802915,
#       'lng': -89.6135593697085},
#      'southwest': {'lat': 21.0000179197085, 'lng': -89.6162573302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '404c7db63b0a559ed74da23c3471f08e682e6b63',
#    'name': 'Osteria Piccoli',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 270,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103732674933667266467/photos">OSTERIA PICCOLI</a>'],
#      'photo_reference': 'CmRaAAAALONtiCV67_qBZl8QJaCqflSI2Wt2HS0ys26x7fMjES6JdbP2bT_YOnK_JRAacW9OIqYq5zOBu-sDx9RRTH0kVNJuXEeBUGAxmCuhJw4EGedsIy6817Cv08S-o3wR1DraEhCJq7c-q5Z3_fhV7Yz9UHpCGhRZkTmB3z6I0NBFR4pRzxR6dYAynA',
#      'width': 720}],
#    'place_id': 'ChIJ8cAMZLJ2Vo8RzqIacVgeGAU',
#    'plus_code': {'compound_code': '292P+H2 Mérida, Yucatan, Mexico',
#     'global_code': '76HG292P+H2'},
#    'price_level': 2,
#    'rating': 4.7,
#    'reference': 'ChIJ8cAMZLJ2Vo8RzqIacVgeGAU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 316,
#    'vicinity': 'Calle 30 112 Local 3 x 23 y 25 Yucatán MX, Mérida'},
#   {'geometry': {'location': {'lat': 20.9981762, 'lng': -89.6163722},
#     'viewport': {'northeast': {'lat': 20.9995988802915,
#       'lng': -89.6149274697085},
#      'southwest': {'lat': 20.9969009197085, 'lng': -89.61762543029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd4ca110e1db1e30fc089606d6b4587af9d7770b1',
#    'name': 'Burger King',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114053400770644356697/photos">el gallego heredia</a>'],
#      'photo_reference': 'CmRaAAAAAgzrLPbB3XLSgK_9Twq0wU_OaxBtMt4eJfQZYeuVIsnLo7I-1qfuiXITBfjlJKglUuAjysicSa7CBDKZMBwUY-4V5Io7KoJ7EXvAQeYOpqKfbLG8p27eHSvfCIPmMVCOEhDQAckbe7uEjyynmX7pqpcUGhTPye4pq8T2te9Dd4cyEtD8nyXJew',
#      'width': 4128}],
#    'place_id': 'ChIJY9x1Tq12Vo8RJcAtqpexutk',
#    'plus_code': {'compound_code': 'X9XM+7F Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XM+7F'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJY9x1Tq12Vo8RJcAtqpexutk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2382,
#    'vicinity': 'Calle 31 131, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.998244, 'lng': -89.615712},
#     'viewport': {'northeast': {'lat': 20.9995543302915,
#       'lng': -89.6143771197085},
#      'southwest': {'lat': 20.9968563697085, 'lng': -89.61707508029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '327304bb69f98c0f7feb2d06957ba82a5a3bff6f',
#    'name': "McCarthy's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105794800853062679353/photos">Laura Diaz</a>'],
#      'photo_reference': 'CmRaAAAANT88Vu3Yh3ImzXLhhSXknKaxaO9H23RqP0lv3pwDNmHdyIWGK54O60LpHQbT8KI35It1jRWjGzpLX4TnsxCjrYTVHJ-yZEUal_-17COv2-UsnnQfhvU7qxomQNLZmFXxEhClKsGUG_Kk9Iu0O_wwaqdHGhQzEEwLHRytPBhWRZhvLG3PeJrebQ',
#      'width': 400}],
#    'place_id': 'ChIJAQMIqrJ2Vo8RyNB-NE2HXFw',
#    'plus_code': {'compound_code': 'X9XM+7P Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XM+7P'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJAQMIqrJ2Vo8RyNB-NE2HXFw',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3170,
#    'vicinity': 'Calle 30 #132 A x11A, Itzimná, Mérida'},
#   {'geometry': {'location': {'lat': 20.9982109, 'lng': -89.6179903},
#     'viewport': {'northeast': {'lat': 20.9995748802915,
#       'lng': -89.6165531697085},
#      'southwest': {'lat': 20.9968769197085, 'lng': -89.61925113029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4269562c43401dbbe9dfaec5e18cee175f945ee6',
#    'name': "Trotter's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1718,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106362701461480695113/photos">Arturo Gonzalez</a>'],
#      'photo_reference': 'CmRaAAAAyPeKAoo4EPkmzVNN412W5kJtb0FzCzkFfi6dCdnF9decZ15KZXUdOs17RnIBq4sFb33HWwCve-a3VKoOfW8cLdhgWKlokiVK-hiXAh8XaAhAERxNB-NurBlOtSm-DICfEhD506tBZlRTVCJOrPkroIYOGhRYp2Dmf-ChC-1KLZcg9iqOJbAntg',
#      'width': 2430}],
#    'place_id': 'ChIJgbGOKq12Vo8RqhK2SdKJzdQ',
#    'plus_code': {'compound_code': 'X9XJ+7R Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+7R'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJgbGOKq12Vo8RqhK2SdKJzdQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 659,
#    'vicinity': 'Calle 31 no.134, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9979932, 'lng': -89.6192654},
#     'viewport': {'northeast': {'lat': 20.99931013029151,
#       'lng': -89.6180513197085},
#      'southwest': {'lat': 20.9966121697085, 'lng': -89.6207492802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4252e57570fa180a1d3d09866a916ad39b4fe3af',
#    'name': 'Little Caesars Pizza',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2336,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100683313379316869131/photos">Alexander Escobar</a>'],
#      'photo_reference': 'CmRaAAAA9obMZtXoG3-seX0Krdr_Lxa2zoyiZ9b_6vWIXB5qTPNAzDQhP2B5lU4JO5eygTFRLEz6apJQJhCZoc0R2_jKnARxiXy2Kz4cjM1sIKfEYMuSPnBBUT3jldEqQGpW0818EhCmFwfK0fZ81q97p2HRmUVLGhRPFvEacLsj6s5BRnjoLh85-MB-uQ',
#      'width': 4160}],
#    'place_id': 'ChIJF4Txyqx2Vo8RcCd1I-3_uDg',
#    'plus_code': {'compound_code': 'X9XJ+57 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+57'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJF4Txyqx2Vo8RcCd1I-3_uDg',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 462,
#    'vicinity': 'Calle 31 140, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9994186, 'lng': -89.61927899999999},
#     'viewport': {'northeast': {'lat': 21.0007238302915,
#       'lng': -89.6182016697085},
#      'southwest': {'lat': 20.9980258697085, 'lng': -89.6208996302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0619946d4bf8bf32d131946ea8a2daab4a1b5295',
#    'name': "Mago's Restaurante",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2192,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117079633809751029661/photos">Mago&#39;s Restaurante</a>'],
#      'photo_reference': 'CmRaAAAAw2XIVde0nV9zGLrJJiVBi-D97k-tnC6kc5AUdR5pJ99Vl7g8pclC61BkrPHg2nDeR2blq9C8gBIpe5NgVZi0Xyfb-h2XoYVcrEymb5zxMF85XrzKSxf8XoldlmPdCnY5EhC0RbnMF9MdNkuYCVQM3xzAGhRfUc83RE-zxE87tb2hrhuNkd0-sw',
#      'width': 3386}],
#    'place_id': 'ChIJK3zxq3N3Vo8R2ggPcP6c71c',
#    'plus_code': {'compound_code': 'X9XJ+Q7 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+Q7'},
#    'rating': 5,
#    'reference': 'ChIJK3zxq3N3Vo8R2ggPcP6c71c',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Calle 13 382, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9972041, 'lng': -89.61566289999999},
#     'viewport': {'northeast': {'lat': 20.9985708802915,
#       'lng': -89.61451686970848},
#      'southwest': {'lat': 20.9958729197085, 'lng': -89.6172148302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '33d1643c2c8b1e271092a0b8c43c39729d21c7f9',
#    'name': 'Wings Wagon',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111179093898473649398/photos">Edson Mota Rodríguez</a>'],
#      'photo_reference': 'CmRaAAAAKRpcOxoQEHZjEx1ixlZ84xgRkg50-IFj_84BpvaXFqw8RGTV-orTBNHZmAS-Ygo92GlihLmvexTxtz1t0zCaB_myKsnqactIppQTpSTPGFb0HWczed5hq7MspWYglwvmEhCrz3k3oZDzdBOHCDxmh_TJGhRpNPXdU3fJu1WUQXWM8kt-lHQGSg',
#      'width': 3264}],
#    'place_id': 'ChIJe2eMV01xVo8RrEnoQoPqBq0',
#    'plus_code': {'compound_code': 'X9WM+VP Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WM+VP'},
#    'reference': 'ChIJe2eMV01xVo8RrEnoQoPqBq0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '97100, Prolongación Paseo Montejo 446, Itzimná, Mérida'},
#   {'geometry': {'location': {'lat': 20.9982613, 'lng': -89.6200873},
#     'viewport': {'northeast': {'lat': 20.9995978302915,
#       'lng': -89.61873581970849},
#      'southwest': {'lat': 20.9968998697085, 'lng': -89.6214337802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '7392d474b8ef22db9a4e6e9f033b159cea9d9c3f',
#    'name': 'Tacos Doña Chona',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 746,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101247493105307510885/photos">Andrés Covarrubias Lopez</a>'],
#      'photo_reference': 'CmRaAAAACCl7EdIPZNf9WZnFBJbUIEzHJdY70xWewlN8peFGi7H05eG1A_0_fCPeBeHNPOtcJ6dIwTlONAaLku9cgbs9nx3jvQJ_1rOfaL5Sy5QIs50ujSOzyLoPXXkNKO5wrt__EhD2XBfLVUs31DQoKkiIOtcOGhTBEgDr7vda2psEhHPdwSLw5lckrQ',
#      'width': 891}],
#    'place_id': 'ChIJfSFOZBl3Vo8RMKSzmbuK8-0',
#    'plus_code': {'compound_code': 'X9XH+8X Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XH+8X'},
#    'reference': 'ChIJfSFOZBl3Vo8RMKSzmbuK8-0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 31 #145 local A x 38 y 40, Circuito Colonias, Mérida'},
#   {'geometry': {'location': {'lat': 20.9965909, 'lng': -89.6191297},
#     'viewport': {'northeast': {'lat': 20.9979177802915,
#       'lng': -89.61777641970849},
#      'southwest': {'lat': 20.9952198197085, 'lng': -89.62047438029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0ea0e0655ca31e424c941fa4014d96705dbce6ec',
#    'name': 'Cocina Esquinita Buenavista',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJIdADAztxVo8RnW7LfxOznss',
#    'plus_code': {'compound_code': 'X9WJ+J8 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WJ+J8'},
#    'rating': 4.4,
#    'reference': 'ChIJIdADAztxVo8RnW7LfxOznss',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9991956, 'lng': -89.6149174},
#     'viewport': {'northeast': {'lat': 21.0005470802915,
#       'lng': -89.61358276970849},
#      'southwest': {'lat': 20.9978491197085, 'lng': -89.61628073029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2bed98f856aec527669089ee6697abca285398e4',
#    'name': 'Taqueria Los Tortuguitas',
#    'place_id': 'ChIJd08xvLJ2Vo8RiZjcLRcE3pg',
#    'plus_code': {'compound_code': 'X9XP+M2 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XP+M2'},
#    'reference': 'ChIJd08xvLJ2Vo8RiZjcLRcE3pg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 28, México, Mérida'},
#   {'geometry': {'location': {'lat': 20.996483, 'lng': -89.61976589999999},
#     'viewport': {'northeast': {'lat': 20.9978100802915,
#       'lng': -89.6184126197085},
#      'southwest': {'lat': 20.99511211970849, 'lng': -89.6211105802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3a57e23155c8ae5d0ba8229529f7f50a2650dd57',
#    'name': 'Tortas & Sopes El Fracc',
#    'place_id': 'ChIJzYeaQlNxVo8RzW0DmBAjhz4',
#    'plus_code': {'compound_code': 'X9WJ+H3 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WJ+H3'},
#    'reference': 'ChIJzYeaQlNxVo8RzW0DmBAjhz4',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 13, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.995689, 'lng': -89.61751319999999},
#     'viewport': {'northeast': {'lat': 20.9969911802915,
#       'lng': -89.61615716970849},
#      'southwest': {'lat': 20.9942932197085, 'lng': -89.6188551302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'dbe2166c547ca4710b4159e1e79c568b93d2fa43',
#    'name': 'Zhen Liying',
#    'place_id': 'ChIJq6qq-lJxVo8RaQ2CCowNCUk',
#    'rating': 3.5,
#    'reference': 'ChIJq6qq-lJxVo8RaQ2CCowNCUk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Gran Plaza Local 93, Fraccionamiento Montejo, Mérida'},
#   {'geometry': {'location': {'lat': 20.9962535, 'lng': -89.6197918},
#     'viewport': {'northeast': {'lat': 20.9975758302915,
#       'lng': -89.6184911197085},
#      'southwest': {'lat': 20.9948778697085, 'lng': -89.6211890802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2c783fae4037137abb9365b11fe3d4f75d3dbd90',
#    'name': '"POLLOS DEL RANCHO AL CARBÓN"',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJC8CFaFNxVo8RshLPPtSkCOs',
#    'plus_code': {'compound_code': 'X9WJ+G3 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WJ+G3'},
#    'rating': 4.3,
#    'reference': 'ChIJC8CFaFNxVo8RshLPPtSkCOs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Calle 58ᶜ 470, Buenavista'},
#   {'geometry': {'location': {'lat': 21.00159, 'lng': -89.6161159},
#     'viewport': {'northeast': {'lat': 21.0028702802915,
#       'lng': -89.6147807697085},
#      'southwest': {'lat': 21.00017231970849, 'lng': -89.61747873029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '11143792cffa2f8508083624d0f1c93913f98cb3',
#    'name': 'RIEH',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106210211641146191508/photos">Nicolas Navarrete</a>'],
#      'photo_reference': 'CmRaAAAA8KhfSRTlG8CIMk6s4xW7jO128mUybLkNL6Rt1zOzlzXnWWsMATRBsZdDhjTLbEQGwa054KAZNKY76_ig4c3i8DoduylyWPtUZZ6gznFfa46zbFhUVnnl5KNaoqgMroT6EhCXQ_YqIMe7sM9LQnizOYxWGhQa-uBSwoL6HiVMheSdelqRKlTOlw',
#      'width': 4032}],
#    'place_id': 'ChIJe9SSha12Vo8R4duZuE3Cc5c',
#    'plus_code': {'compound_code': '292M+JH Mérida, Yucatan, Mexico',
#     'global_code': '76HG292M+JH'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJe9SSha12Vo8R4duZuE3Cc5c',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 97,
#    'vicinity': 'Calle 25 131, Buenavista, Mérida'}],
#  'status': 'OK'}

# %%
#Creating a data frame from trompos_circuito['results']
table_similar_places = pd.DataFrame(trompos_circuito['results'])

#Teacher, the function didn't take my rankby (idk if Ii was doing it wrong, probably yes), but I did it manualy
table_similar_places = table_similar_places.sort_values('rating',ascending=False).reset_index(drop=False)

#Selecting only the desired columns
table_similar_places = table_similar_places[['id', 'name', 'rating', 'user_ratings_total']]

#Renaming the columns to  Place Name, Place Id, Rating, Total of User Ratings.
table_similar_places = table_similar_places.rename(columns={"id": "Place id", "name": "Place Name", "rating" : "Rating", "user_ratings_total" : "Total of User Ratings"})

#Reordering the columns
table_similar_places = table_similar_places[["Place Name", "Place id", "Rating", "Total of User Ratings"]]

table_similar_places
# Out:
#                        Place Name                                  Place id  \
# 0              Mago's Restaurante  0619946d4bf8bf32d131946ea8a2daab4a1b5295
# 1                 Osteria Piccoli  404c7db63b0a559ed74da23c3471f08e682e6b63
# 2                      Mr. Pampas  657620905f41cddeeefd73c87f0038e76d1320b9
# 3                       Trotter's  4269562c43401dbbe9dfaec5e18cee175f945ee6
# 4                     Los Trompos  cf6c67c9eb44c578189fe7afa775b9c87026672f
# 5                   A la pimienta  d39c4485a4687e3717417c89a18cc8e6219ff525
# 6     Los Originales Tacos de Res  7ace37da5f0e3d05373f8b7bfe11c29cd86105fb
# 7                      McCarthy's  327304bb69f98c0f7feb2d06957ba82a5a3bff6f
# 8                            RIEH  11143792cffa2f8508083624d0f1c93913f98cb3
# 9           Pizza del Perro Negro  3da77355187a5c061f10675393003c55e6d23bad
# 10    Cocina Esquinita Buenavista  0ea0e0655ca31e424c941fa4014d96705dbce6ec
# 11  "POLLOS DEL RANCHO AL CARBÓN"  2c783fae4037137abb9365b11fe3d4f75d3dbd90
# 12                Mi Viejo Molino  0525209b56b3dfac93492825024c73986cb1c704
# 13                    Burger King  d4ca110e1db1e30fc089606d6b4587af9d7770b1
# 14           Little Caesars Pizza  4252e57570fa180a1d3d09866a916ad39b4fe3af
# 15                    Zhen Liying  dbe2166c547ca4710b4159e1e79c568b93d2fa43
# 16                    Wings Wagon  33d1643c2c8b1e271092a0b8c43c39729d21c7f9
# 17               Tacos Doña Chona  7392d474b8ef22db9a4e6e9f033b159cea9d9c3f
# 18       Taqueria Los Tortuguitas  2bed98f856aec527669089ee6697abca285398e4
# 19        Tortas & Sopes El Fracc  3a57e23155c8ae5d0ba8229529f7f50a2650dd57
#
#     Rating  Total of User Ratings
# 0      5.0                    2.0
# 1      4.7                  316.0
# 2      4.6                 3935.0
# 3      4.6                  659.0
# 4      4.5                 3130.0
# 5      4.5                  257.0
# 6      4.5                   35.0
# 7      4.5                 3170.0
# 8      4.5                   97.0
# 9      4.4                 1792.0
# 10     4.4                   10.0
# 11     4.3                    3.0
# 12     4.2                 1391.0
# 13     4.1                 2382.0
# 14     4.1                  462.0
# 15     3.5                    4.0
# 16     NaN                    NaN
# 17     NaN                    NaN
# 18     NaN                    NaN
# 19     NaN                    NaN

# %% [markdown]
# F. Complete all the above tasks but using the Python [GoogleMaps](https://github.com/googlemaps/google-maps-services-python) Library. [Here](https://googlemaps.github.io/google-maps-services-python/docs/#module-googlemaps) you can find the documentation.

# %%
import googlemaps

#API Key
gmaps = googlemaps.Client(key='')

# %% [markdown]
# F.A. Use the [*Nearby Seach*](https://developers.google.com/places/web-service/search) Method to find all the restaurant near to the UPY (20.988459, -89.736768) around 2km. In order to fulfill this item you need to:
# * Create a *search_nearby_places* function with the appropiate parameters. It must return a JSON with the results. Places must be ranked by distance.
# * Create a table with the following columns: Name, Place Id, Rating, Place Types, Total of User Ratings.

# %%
def search_nearby_places():
    """
    Function to search naer places 
    to UPY according to the parameters with 
    the google library.

    Parameters:
    None
    
    Returns:
    A json
    """
    results = gmaps.places_nearby(location = '20.988459, -89.736768', radius = 2000, type = 'restaurant')
    return results

# %%
UPY_restaurants_google = search_nearby_places()
UPY_restaurants_google
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 20.9943362,
#      'lng': -89.72616219999999},
#     'viewport': {'northeast': {'lat': 20.99568418029151,
#       'lng': -89.72480971970849},
#      'southwest': {'lat': 20.9929862197085, 'lng': -89.72750768029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '51215063e260371f31be9c48b4b35f276677d8df',
#    'name': 'La Glorieta (Cocina y Pizzería)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112470977400009114281/photos">Óscar Albornoz</a>'],
#      'photo_reference': 'CmRaAAAAI1Ky30sVGcaRJnWRm0HN3zxrk0cHsQH3axa8iSzKoPiv8FzxaHNybkuLE9PD8-Q4f4igqd3PaEJuVqwOQZ4PQIC9uSsitdwuKMVAr1UmIVMWrX1C9TPW3mr-YXEnDPX2EhDxBIhJGavwPw804uXudLNPGhRZ6rK2G2PLeqD8KJJeFk7yB9JF_g',
#      'width': 3024}],
#    'place_id': 'ChIJC9i7XEsNVo8Ro2-sdS45rBg',
#    'plus_code': {'compound_code': 'X7VF+PG Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7VF+PG'},
#    'rating': 4.1,
#    'reference': 'ChIJC9i7XEsNVo8Ro2-sdS45rBg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Mérida'},
#   {'geometry': {'location': {'lat': 20.9892802, 'lng': -89.7235666},
#     'viewport': {'northeast': {'lat': 20.9905874802915,
#       'lng': -89.7222163197085},
#      'southwest': {'lat': 20.9878895197085, 'lng': -89.7249142802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0c95338760a6b57abb8c90f793757973d37a3858',
#    'name': 'Mr. Cazuelas',
#    'place_id': 'ChIJ3WHHeJkMVo8RO_z2pfoDFZg',
#    'plus_code': {'compound_code': 'X7QG+PH Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7QG+PH'},
#    'rating': 4,
#    'reference': 'ChIJ3WHHeJkMVo8RO_z2pfoDFZg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Calle 89, Caucel'},
#   {'geometry': {'location': {'lat': 20.993318, 'lng': -89.72394469999999},
#     'viewport': {'northeast': {'lat': 20.9947245302915,
#       'lng': -89.72259806970848},
#      'southwest': {'lat': 20.9920265697085, 'lng': -89.72529603029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '30608abf06a3d55762f3cf88c6ebfb59e6600755',
#    'name': 'El Rincón Del Tabas',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100844704817294711241/photos">Victor Suarez</a>'],
#      'photo_reference': 'CmRaAAAA9MnWhBtW_W4WMIaXJyrz9UlMp5FidO6EFF1zeXpiOCx_GoN06nXwzIXsWAR5q74udICncHbZBH8fK22bKDKYnHhQ3Jx4gZ9nlzEO4Oto58TxEaKTUW2kGgbPBdAd5azmEhBlTqVLVXAGR9OkK4wRc9qcGhQVD0F3I1eH0lVo__apBrDHX75n3A',
#      'width': 4000}],
#    'place_id': 'ChIJn4UFHpwMVo8RZOfFHQCuIwo',
#    'plus_code': {'compound_code': 'X7VG+8C Mérida Municipality, Yucatan, Mexico',
#     'global_code': '76GGX7VG+8C'},
#    'rating': 5,
#    'reference': 'ChIJn4UFHpwMVo8RZOfFHQCuIwo',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Calle 77-A 77'},
#   {'geometry': {'location': {'lat': 20.9935837, 'lng': -89.7235008},
#     'viewport': {'northeast': {'lat': 20.9951064302915,
#       'lng': -89.7221607697085},
#      'southwest': {'lat': 20.9924084697085, 'lng': -89.7248587302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4084cb111246633c21ff68a31c522f01099d8f27',
#    'name': 'Moyoyos burger',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111027710432853138137/photos">Moyoyos Kennels</a>'],
#      'photo_reference': 'CmRaAAAAyIepBI9rLxGbuBQmY5hTQVRzrqhZlpygy50kxwUgI6TlRoyJtoYvJqMZkFtXixueHhm-PdCUpedqwDOOGH8GcwhEuMQEZTLRIigRjoUHx0iHqDjrtRuNTW7kSHyamemnEhDkV8XjvXcp3hxtVGlxjC2QGhR1ATnwF0unVy7avUShnUMQRe-r5A',
#      'width': 1080}],
#    'place_id': 'ChIJqxQ91h0NVo8R52sc8a1HlvE',
#    'plus_code': {'compound_code': 'X7VG+CH Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7VG+CH'},
#    'reference': 'ChIJqxQ91h0NVo8R52sc8a1HlvE',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 77 800'},
#   {'geometry': {'location': {'lat': 20.9887511, 'lng': -89.72230379999999},
#     'viewport': {'northeast': {'lat': 20.9900881302915,
#       'lng': -89.7209540197085},
#      'southwest': {'lat': 20.98739016970849, 'lng': -89.7236519802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '752346a25e2f154673bf82a953e3efba988575a4',
#    'name': 'Cocina economica "El sabor de doña antonia"',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 363,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117281795601236564539/photos">Asucena Pech</a>'],
#      'photo_reference': 'CmRaAAAAuTex-VvjRHYlVyQH7mQuPdjrdyHtlB41E5BpPc9biionegxYUvxkZG4DrQ_5bOFUWWEHMjI6Yultk8WKU47Xgs6YvqqM2a6x9ot8Ihtnm9pJBFSllKln8KM5tIOZ0K8NEhBGkK8ky0Cyg_qA6xOORKrPGhRz8PZqD1S2kk4M4dyFLLYPeguAOw',
#      'width': 640}],
#    'place_id': 'ChIJaQJm928NVo8RAN8mnDmvYEk',
#    'plus_code': {'compound_code': 'X7QH+G3 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7QH+G3'},
#    'reference': 'ChIJaQJm928NVo8RAN8mnDmvYEk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 91 97314 Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 20.9973152, 'lng': -89.7256647},
#     'viewport': {'northeast': {'lat': 20.9986653802915,
#       'lng': -89.72428056970848},
#      'southwest': {'lat': 20.9959674197085, 'lng': -89.72697853029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '94a25dcf077a6066604267e21c4d8d35b2d77ce9',
#    'name': 'Cemitas Poblanas Doña Dulce',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107050260111115920816/photos">Jose Rios</a>'],
#      'photo_reference': 'CmRaAAAABJ8ha7TVHqOHsd2NKFyxNVdixR91b0iDcegizVwFvn0YZc6gJ4VuFNVX8-Z1lALxjIpcRSiWegJlaZYnfGhEICvl-ZDApOm5hfiVNhurW0h0Us4pR5vd-Wn8ZmZRJ3ApEhBpZxBX4b-SgMmrUMgKXBiBGhRpwkDceq-RJRKtU4-XdvlSxAGw5g',
#      'width': 1920}],
#    'place_id': 'ChIJ-18misANVo8R8_gP-uVUAMY',
#    'plus_code': {'compound_code': 'X7WF+WP Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7WF+WP'},
#    'rating': 4.8,
#    'reference': 'ChIJ-18misANVo8R8_gP-uVUAMY',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 22,
#    'vicinity': 'calle 112b x 67 y 67a los almendros, 97314, Mérida'},
#   {'geometry': {'location': {'lat': 20.9975307, 'lng': -89.7256029},
#     'viewport': {'northeast': {'lat': 20.99887853029151,
#       'lng': -89.72428761970848},
#      'southwest': {'lat': 20.9961805697085, 'lng': -89.7269855802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'e22b717561fbd87a9fbd561e7e92ce6ac9c2ae92',
#    'name': 'Hamburguesas Maaaa de la 112.',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 750,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118028157930418523984/photos">Yoshua Gonzalez</a>'],
#      'photo_reference': 'CmRaAAAABOo-ujJNJVfiRFHUJ-Rf6ArMzJFsq1--8lYm_0T4NtIG_4Rj7yNxdkmVVauTQ3Fv_S_3b3xzPPpL9NDRftY22lc9R1CyGfrDAE2Ow42aYUxQACHcZHxveJvUpqESYvj1EhAENQJ-mX_wBrHSLqg1354dGhTWAGkiwuSzpoHLrReZOKelhvFC2w',
#      'width': 750}],
#    'place_id': 'ChIJXTh3gaoNVo8RovFdjQ-lN10',
#    'plus_code': {'compound_code': 'X7XF+2Q Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XF+2Q'},
#    'rating': 3.7,
#    'reference': 'ChIJXTh3gaoNVo8RovFdjQ-lN10',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Calle 112B'},
#   {'geometry': {'location': {'lat': 20.996515, 'lng': -89.72460749999999},
#     'viewport': {'northeast': {'lat': 20.9978002802915,
#       'lng': -89.7232555697085},
#      'southwest': {'lat': 20.9951023197085, 'lng': -89.7259535302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '20ae18c28bf7f1ac4b157bfa6f829e1147a42629',
#    'name': 'Carnívoros',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103470461646416855876/photos">eduardo rincon gamboa</a>'],
#      'photo_reference': 'CmRaAAAAgM01q_MkNgoYykwtqn8j8tdOPyAohQjZFsCVTH2EYqSyJziaidDBbHT7lwLR7USIgzsMvbgeIRMiopZ5cNMGlL1UIxfggJLWxmlZ9V8YjEN13c0vZ-nNv_FB43G5TwIGEhD5cZuks4pNzaMsfzlcTLuPGhQqlXSXEe8zXCaFsEn2ZnhLljupaw',
#      'width': 5312}],
#    'place_id': 'ChIJx9nxwp0MVo8RvujKFHXH6H4',
#    'plus_code': {'compound_code': 'X7WG+J5 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7WG+J5'},
#    'rating': 4.2,
#    'reference': 'ChIJx9nxwp0MVo8RvujKFHXH6H4',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 40,
#    'vicinity': 'Calle 69 97314, Ciudad Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 20.99656909999999,
#      'lng': -89.72424629999999},
#     'viewport': {'northeast': {'lat': 20.9978341802915,
#       'lng': -89.7228937197085},
#      'southwest': {'lat': 20.9951362197085, 'lng': -89.7255916802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '60ed2c5d1a4c991c3ad222d17aa16f58e6a3caf1',
#    'name': 'Modelorama',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJozhU3J0MVo8RKZTNG5qZyu4',
#    'plus_code': {'compound_code': 'X7WG+J8 Mérida Municipality, Yucatan, Mexico',
#     'global_code': '76GGX7WG+J8'},
#    'rating': 4.8,
#    'reference': 'ChIJozhU3J0MVo8RKZTNG5qZyu4',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'bar',
#     'liquor_store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Calle 69 0'},
#   {'geometry': {'location': {'lat': 20.9998287, 'lng': -89.72573709999999},
#     'viewport': {'northeast': {'lat': 21.0011944302915,
#       'lng': -89.72449006970848},
#      'southwest': {'lat': 20.9984964697085, 'lng': -89.72718803029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'de3a373bd6aaf3d8cea31dd92d32dac99c827645',
#    'name': 'La BOMBA DEL SABOR',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111038143495180908056/photos">Elian Yoryet Casanueva Saldivar</a>'],
#      'photo_reference': 'CmRaAAAAaaUh2Q9M8pByQo277vi1b2EzLycov8NBHEJo9UtJM6GVKhq_w1HCbGdSiL5ixbpEGEzpwkr5qZdEPpOby3_zBMsOulEMRfEK_olucu7XkNcMwcShw_DTUfaL0gipSPeqEhDcJC2tAmo-ltBophLHfPaFGhRY8hZSlClGJUhwceVMeb0D3CykPg',
#      'width': 1080}],
#    'place_id': 'ChIJXzbguNgLVo8RnxttdBhYakc',
#    'plus_code': {'compound_code': 'X7XF+WP Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XF+WP'},
#    'rating': 5,
#    'reference': 'ChIJXzbguNgLVo8RnxttdBhYakc',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Calle 112B #713D, Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 20.996409, 'lng': -89.72260709999999},
#     'viewport': {'northeast': {'lat': 20.9977818302915,
#       'lng': -89.7212593197085},
#      'southwest': {'lat': 20.9950838697085, 'lng': -89.72395728029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'd57b0922384b5e843203b7c256c5bbaf1cfb0899',
#    'name': 'La Carlota',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108046929243728680035/photos">René Cortés</a>'],
#      'photo_reference': 'CmRaAAAA8luv5gz68iAkHnEoq26VIqHq8X1eZAz1sIlGXcAshWzu6Gk4Q-qcDzZVQwFDZcT1w8WTiqBcq8dXu8G4srCDcy2jxooSSd0DBRtYox-6eJa_ZhoQ0NE1dYj_6LQu-wl7EhAP7qaDNufSzfwLxD8xOxMQGhQoQJ1Q7-Eigjdx0mp7hhWtwJhjAg',
#      'width': 1280}],
#    'place_id': 'ChIJVWRJiW8NVo8R7E46087W96E',
#    'plus_code': {'compound_code': 'X7WG+HX Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7WG+HX'},
#    'rating': 5,
#    'reference': 'ChIJVWRJiW8NVo8R7E46087W96E',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Calle 69 #828, Los Almendros III, Mérida'},
#   {'geometry': {'location': {'lat': 20.99220709999999, 'lng': -89.7200615},
#     'viewport': {'northeast': {'lat': 20.9935498302915,
#       'lng': -89.7187122197085},
#      'southwest': {'lat': 20.9908518697085, 'lng': -89.7214101802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'ff7a39dbe5bb296ca8c72d5c490012a5920ca803',
#    'name': 'The witch burgers',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1223,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110507939685883191760/photos">Emmanuel Pat</a>'],
#      'photo_reference': 'CmRaAAAAkuh6-te5WB8-UCkU0A5CyUHCEXugX5WEEHyjEKxZVFMCJoBqxuLFFNpnFriufHf6Y-5v68NMmx5Sw9knxv5R1ej00AYedAPs9vZjkP-c5fzDzKRRYHfysWjth22P1LkzEhA7OqC0sDw7iho6x7CE7LLpGhR7q7X3NuAplS3uaFqRpeCM8FMfBg',
#      'width': 2167}],
#    'place_id': 'ChIJk8-rWwgNVo8RhVnpRaHabZ8',
#    'plus_code': {'compound_code': 'X7RH+VX Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7RH+VX'},
#    'rating': 5,
#    'reference': 'ChIJk8-rWwgNVo8RhVnpRaHabZ8',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '#803, Calle 77D, Mérida'},
#   {'geometry': {'location': {'lat': 20.9995933, 'lng': -89.7241751},
#     'viewport': {'northeast': {'lat': 21.0010242302915,
#       'lng': -89.72280956970849},
#      'southwest': {'lat': 20.9983262697085, 'lng': -89.7255075302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '09919e36d2c0a0c677b4d17b76c81f4e9880cfe6',
#    'name': 'Panuchos & Salbutes El Almendrito',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 578,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118354559545815287588/photos">Alberto Farfán</a>'],
#      'photo_reference': 'CmRaAAAASUQ41gDasqq4IdoOBCivWW3-3BxVmAR6RBmA9yccm6cQyxjT_QCe2qbxfqKNIglq9t_qnvfefrAiM2O8nawiotv1cXO8zLwuACEQTZ1b_ZwBkd3hRlRWmktJKVI--JksEhATtnHU1IVz0sUXvkayILdOGhTSSTLW38F1ok72yMtcbjzLt_W8Pw',
#      'width': 763}],
#    'place_id': 'ChIJ80ttQuMLVo8RC-oH1Eisi8A',
#    'plus_code': {'compound_code': 'X7XG+R8 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XG+R8'},
#    'rating': 5,
#    'reference': 'ChIJ80ttQuMLVo8RC-oH1Eisi8A',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Calle 61 910B'},
#   {'geometry': {'location': {'lat': 20.9986447, 'lng': -89.7230403},
#     'viewport': {'northeast': {'lat': 20.9999780802915,
#       'lng': -89.7216942697085},
#      'southwest': {'lat': 20.9972801197085, 'lng': -89.7243922302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '6d12df97d6b931d3b914a2a7cc046a2d8ded7bbc',
#    'name': 'HAMBURGUESAS HARAMYYU BIRIZ',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJHdPcMX0LVo8RhSB1GURFT7U',
#    'plus_code': {'compound_code': 'X7XG+FQ Mérida, Yucatan, Mexico',
#     'global_code': '76GGX7XG+FQ'},
#    'reference': 'ChIJHdPcMX0LVo8RhSB1GURFT7U',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 65 905, Ciudad Caucel, Mérida'},
#   {'geometry': {'location': {'lat': 21.0008062, 'lng': -89.7234368},
#     'viewport': {'northeast': {'lat': 21.0022281302915,
#       'lng': -89.7220739697085},
#      'southwest': {'lat': 20.9995301697085, 'lng': -89.72477193029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '8ee8315cd353bbd3b739792631df0ea0e28f913a',
#    'name': 'PerryBurguer',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117293953942763458122/photos">Antonio Hernandez chac</a>'],
#      'photo_reference': 'CmRZAAAAdZRPHbW2p6-_ZpXUUCQfJHHiqpnEUEcc2Ii2e3qCLy8yKxz-x04fxKPXz2fYeBzFBrW8Oe8unt7S0ZszUoCRLmtF8xHWhevOCUKSUnAI19ED0w_yWkDf2GWJM6El3gTtEhCEgIagnKYt81cCuf7ifWy2GhRh9Y_PNj1Z8eSbDbGPMphpEldozw',
#      'width': 4160}],
#    'place_id': 'ChIJldA29UgLVo8Rj6HAXz7I2iM',
#    'plus_code': {'compound_code': '272G+8J Mérida, Yucatan, Mexico',
#     'global_code': '76HG272G+8J'},
#    'rating': 4.5,
#    'reference': 'ChIJldA29UgLVo8Rj6HAXz7I2iM',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Unnamed Road, 97314'}],
#  'status': 'OK'}

# %%
#Create again a json, take the objects of UPY_restaurants['results'] to string and order them in columns
table_UPY_google = pd.read_json(json.dumps(UPY_restaurants_google['results']), orient='columns')

#Selecting only the 'name', 'id', 'rating', 'types', 'user_ratings_total' columns
table_UPY_google = table_UPY_google[['name', 'id', 'rating', 'types', 'user_ratings_total']]

#Renaming the columns 
table_UPY_google = table_UPY_google.rename(columns={"name" : "Name", "id" : "Place Id", "rating" : "Rating", "types" : "Place Types", "user_ratings_total" : "Total of User Ratings"})

table_UPY_google
# Out:
#                                            Name  \
# 0               La Glorieta (Cocina y Pizzería)
# 1                                  Mr. Cazuelas
# 2                           El Rincón Del Tabas
# 3                                Moyoyos burger
# 4   Cocina economica "El sabor de doña antonia"
# 5                   Cemitas Poblanas Doña Dulce
# 6                 Hamburguesas Maaaa de la 112.
# 7                                    Carnívoros
# 8                                    Modelorama
# 9                            La BOMBA DEL SABOR
# 10                                   La Carlota
# 11                            The witch burgers
# 12            Panuchos & Salbutes El Almendrito
# 13                  HAMBURGUESAS HARAMYYU BIRIZ
# 14                                 PerryBurguer
#
#                                     Place Id  Rating  \
# 0   51215063e260371f31be9c48b4b35f276677d8df     4.1
# 1   0c95338760a6b57abb8c90f793757973d37a3858     4.0
# 2   30608abf06a3d55762f3cf88c6ebfb59e6600755     5.0
# 3   4084cb111246633c21ff68a31c522f01099d8f27     NaN
# 4   752346a25e2f154673bf82a953e3efba988575a4     NaN
# 5   94a25dcf077a6066604267e21c4d8d35b2d77ce9     4.8
# 6   e22b717561fbd87a9fbd561e7e92ce6ac9c2ae92     3.7
# 7   20ae18c28bf7f1ac4b157bfa6f829e1147a42629     4.2
# 8   60ed2c5d1a4c991c3ad222d17aa16f58e6a3caf1     4.8
# 9   de3a373bd6aaf3d8cea31dd92d32dac99c827645     5.0
# 10  d57b0922384b5e843203b7c256c5bbaf1cfb0899     5.0
# 11  ff7a39dbe5bb296ca8c72d5c490012a5920ca803     5.0
# 12  09919e36d2c0a0c677b4d17b76c81f4e9880cfe6     5.0
# 13  6d12df97d6b931d3b914a2a7cc046a2d8ded7bbc     NaN
# 14  8ee8315cd353bbd3b739792631df0ea0e28f913a     4.5
#
#                                           Place Types  Total of User Ratings
# 0   [restaurant, food, point_of_interest, establis...                   14.0
# 1   [restaurant, food, point_of_interest, establis...                    3.0
# 2   [restaurant, food, point_of_interest, establis...                    2.0
# 3   [restaurant, food, point_of_interest, establis...                    NaN
# 4   [restaurant, food, point_of_interest, establis...                    NaN
# 5   [restaurant, food, point_of_interest, establis...                   22.0
# 6   [restaurant, food, point_of_interest, establis...                    6.0
# 7   [restaurant, food, point_of_interest, establis...                   40.0
# 8   [convenience_store, bar, liquor_store, restaur...                    4.0
# 9   [restaurant, food, point_of_interest, establis...                    2.0
# 10  [meal_delivery, restaurant, food, point_of_int...                    4.0
# 11  [restaurant, food, point_of_interest, establis...                    1.0
# 12  [restaurant, food, point_of_interest, establis...                    1.0
# 13  [restaurant, food, point_of_interest, establis...                    NaN
# 14  [restaurant, food, point_of_interest, establis...                   11.0

# %% [markdown]
# F.B. Create a function to Find the Place Id given Place Name (String) and Location (Lat/Lont Tuple).

# %%
def place_id(name, lat, lon):
    """
    Function to find a place given a place name and a location.

    Parameters:
    latitude: float (latitude from the places we are searching by)
    longitude: float (longitude from the places we are searching by)
    name: string (name of the places)
    
    Returns:
    A string with the id
    """
    results = gmaps.find_place(input = name, input_type = 'textquery', location_bias = 'point:{}, {}'.format(lat,lon))['candidates'][0]['place_id']
    return results #A string

# %%
Carnívoros_id_google = place_id('Carnívoros', 20.996515, -89.724)
Carnívoros_id_google
# Out:
# 'ChIJx9nxwp0MVo8RvujKFHXH6H4'

# %% [markdown]
# F.C. Find the Place ID of the following places using your functions:
# * McCarthy's Irish Pub - Caucel
# * Starbucks Montejo
# * Los Trompos Circuito

# %%
mccarthys_caucel_google = place_id("McCarthy's Irish Pub - Caucel", 20.999940, -89.682572) 

starbucks_montejo_google = place_id("Starbucks Montejo",20.984971, -89.618131)

trompos_circuito_google = place_id("Los Trompos Circuito",20.984971, -89.618131)

print("McCarthy's Irish Pub - Caucel: {}".format(mccarthys_caucel_google))
print("Starbucks Montejo: {}".format(starbucks_montejo_google))
print("Los Trompos Circuito: {}".format(trompos_circuito_google))
# Out:
# McCarthy's Irish Pub - Caucel: ChIJJyKKOKB0Vo8RCQcxkUw6hp8
# Starbucks Montejo: ChIJaUUfylFxVo8RgEGjoansPbc
# Los Trompos Circuito: ChIJpVKXOq12Vo8RK4bUWILT9dI

# %% [markdown]
# F.D. Use the [*Place Details*](https://developers.google.com/places/web-service/details#PlaceDetailsResults) Method to find the Reviews of a Place in English and Spanish. In order to fulfill this item you need to:
# * Create a *find_reviews* function with the appropiate parameters. It must return a JSON with the results.
# * Create a table with the following columns: Author Name, Language, Rating, Text, Time.

# %%
def find_reviews(placeid):
    """
    Function to  find the Reviews of a Place 
    in English and Spanish given the place id.

    Parameters:
    placeid: string (the id of the place)
    
    Returns:
    A json                                  
    """                   
    results = gmaps.place(place_id = placeid, fields = ['review'], language = 'en, es')
    return results

# %%
mccarthys_caucel_reviews_google = find_reviews('ChIJJyKKOKB0Vo8RCQcxkUw6hp8')
mccarthys_caucel_reviews_google
# Out:
# {'html_attributions': [],
#  'result': {'reviews': [{'author_name': 'David Guillermo',
#     'author_url': 'https://www.google.com/maps/contrib/108835593422479203315/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh6.ggpht.com/-qROp1y6xMq0/AAAAAAAAAAI/AAAAAAAAAAA/xrBzWrF6AUo/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#     'rating': 3,
#     'relative_time_description': 'a month ago',
#     'text': 'They need person to regulate the sound inside the place',
#     'time': 1566612760},
#    {'author_name': 'Patrick',
#     'author_url': 'https://www.google.com/maps/contrib/110157321358354256956/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh5.ggpht.com/-IA6GV8CxUH8/AAAAAAAAAAI/AAAAAAAAAAA/B3p7A3S2beM/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'One of the best pubs around.\nGreat service, great menu, fair prices, superb music.',
#     'time': 1518688093},
#    {'author_name': 'Toni Aguilar',
#     'author_url': 'https://www.google.com/maps/contrib/103748126392715557478/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh5.ggpht.com/-NJV60otC-hE/AAAAAAAAAAI/AAAAAAAAAAA/IUxjmuO87WE/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'Rockers, music lovers in general will enjoy this place alot, good variety of beer and drinks also the food is amaizing at a good price points! Ambience is perfect and live music on stage couple days a week make it better! Go and enjoy yourself',
#     'time': 1516852970},
#    {'author_name': 'Islas',
#     'author_url': 'https://www.google.com/maps/contrib/106046994845938765413/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh4.ggpht.com/-meMgiNgJfqM/AAAAAAAAAAI/AAAAAAAAAAA/izRi6ikb7yI/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'I love this place, one of the best places to drink a good beer and listen rock music and the food is really awesome',
#     'time': 1522860496},
#    {'author_name': 'monica ravell',
#     'author_url': 'https://www.google.com/maps/contrib/117122126063276406803/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh5.ggpht.com/-7MhrgLUCsxw/AAAAAAAAAAI/AAAAAAAAAAA/VVzvMql2IEs/s128-c0x00000000-cc-rp-mo/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'Great place to listen to good rock',
#     'time': 1531876412}]},
#  'status': 'OK'}

# %%
#Creating a data frame for the find_reviews with the id of mccarthys caucel
table_find_reviews = pd.DataFrame(mccarthys_caucel_reviews_google['result']['reviews'])

#changing the time format
table_find_reviews['time'] = pd.to_datetime(table_find_reviews['time'],unit='s') 

#Choosing the Author Name, Language, Rating, Text, Time columns.
table_find_reviews = table_find_reviews[['author_name', 'language', 'rating', 'time', 'text']]

#Renaming the columns to Author Name, Language, Rating, Text, Time.
table_find_reviews = table_find_reviews.rename(columns={"author_name" : "Author Name", "language" : "Language", "rating" : "Rating", "text" : "Text", "time" : "Time" })

table_find_reviews
# Out:
#        Author Name Language  Rating                Time  \
# 0  David Guillermo       en       3 2019-08-24 02:12:40
# 1          Patrick       en       5 2018-02-15 09:48:13
# 2     Toni Aguilar       en       5 2018-01-25 04:02:50
# 3            Islas       en       5 2018-04-04 16:48:16
# 4    monica ravell       en       5 2018-07-18 01:13:32
#
#                                                 Text
# 0  They need person to regulate the sound inside ...
# 1  One of the best pubs around.\nGreat service, g...
# 2  Rockers, music lovers in general will enjoy th...
# 3  I love this place, one of the best places to d...
# 4                 Great place to listen to good rock

# %% [markdown]
# F.E. Find similar places to Los Trompos Circuito. Rank them by its "Prominence". In order to fulfill this item you need to:
# * Create a *find_similar* function with the appropiate parameters. It must return a JSON with the results.
# * Create a table with the following columns: Place Name, Place Id, Rating, Total of User Ratings.

# %%
def find_similar():
    """
    Function to similar places to 'Los Trompos Circuito', rank them by its prominence.

    Parameters:
    None
    
    Returns:
    A json
    """
    results = gmaps.places_nearby(location = '20.998694, -89.6175974', radius =  500, type = 'restaurant', rank_by = 'prominence')
    return results

# %%
trompos_circuito_google = find_similar()
trompos_circuito_google
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAABxR57YE8TXCrpAl9qBSHj3Au3nRngSCgM2poZ4W2s8mnoWQXXwUntYIaZzdZI6pn0fRaCQBGpQ4d59ry8g3xRwb5NZ2P6nZurFbdh_qtevVPWjSabq_WHpY_G287fGfX1Mv-sTM2Of4qhTh9_SvhmnG-e1XTcC0oP_WMdfK-nnu6OYzmU1kqqCao7of_sH4CaPAq1ALXkfsGtc1qkfpzTdHC2q4D2wy3Q5As-CMF0RFTKBT2q8NRtgoNbGuxF-JIu0v9qjDIxlgscRhFbn1mU-Mwf9QvgDCWV16BwvxTH89JTuPaTKWiR9j4uVuN9ffxhWnuPpCM5y1nrEUl4U7lcK2Yo3SK2QoviPZcwptERj8hebfIhuPbtaDXhGpSy7w3bXA4qw1bBBRvXOAXb0QtcQSENg42QOU3bAGA6wzdzAAXxIaFGhrwX2k7S-l6Vh6YTsIssbB0FPk',
#  'results': [{'geometry': {'location': {'lat': 20.99881,
#      'lng': -89.61743539999999},
#     'viewport': {'northeast': {'lat': 21.0000983802915,
#       'lng': -89.61603351970848},
#      'southwest': {'lat': 20.9974004197085, 'lng': -89.6187314802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'cf6c67c9eb44c578189fe7afa775b9c87026672f',
#    'name': 'Los Trompos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100748773694559340701/photos">TecnoMaya</a>'],
#      'photo_reference': 'CmRaAAAAk7iBbfZDfpOvQvmOVfDZp-qPAZrmAArKViUZwakU48iFHiNyWsGjdTljPoCLKw6Pfq7utSjV4rEsCo8pWW7zmWOsR2ddYWMXFvHoStl3AQ891PyZKRsJnPFD8wQ-rkWnEhDP31i_yaUyLOMrQo_7Ae2aGhRyDVaJyhcTahRFK2TSqkrfCQ6m8w',
#      'width': 5312}],
#    'place_id': 'ChIJpVKXOq12Vo8RK4bUWILT9dI',
#    'plus_code': {'compound_code': 'X9XM+G2 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XM+G2'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJpVKXOq12Vo8RK4bUWILT9dI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3130,
#    'vicinity': 'Calle 31 x 32 #133, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9984348, 'lng': -89.6177091},
#     'viewport': {'northeast': {'lat': 20.9998387302915,
#       'lng': -89.61637096970848},
#      'southwest': {'lat': 20.9971407697085, 'lng': -89.61906893029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0525209b56b3dfac93492825024c73986cb1c704',
#    'name': 'Mi Viejo Molino',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100105566345961373500/photos">jhonathan izquierdo</a>'],
#      'photo_reference': 'CmRaAAAAgl5crax6m2TyfW0AqK89mj_z6FNrJUtqYmZfd_soJMEgHRQuZBFGdFKXHEgBWw3azxQMy1b03aBaXr3DLLQsxgmwlsGh2VuaKaqxVTepkwON2nynYRJyVVBz7rgPVQ1jEhCu7fnlk0BPYRmWruqNARXTGhTRE-KPbOUfirVNd0QNg_b1wuP6ow',
#      'width': 4160}],
#    'place_id': 'ChIJA2XvLq12Vo8RmHzVkbC-a1M',
#    'plus_code': {'compound_code': 'X9XJ+9W Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+9W'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJA2XvLq12Vo8RmHzVkbC-a1M',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1391,
#    'vicinity': 'Circuito Colonias 132, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9981513, 'lng': -89.6188694},
#     'viewport': {'northeast': {'lat': 20.9995989802915,
#       'lng': -89.61753946970849},
#      'southwest': {'lat': 20.99690101970849, 'lng': -89.6202374302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3da77355187a5c061f10675393003c55e6d23bad',
#    'name': 'Pizza del Perro Negro',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 576,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114062633533081902517/photos">Pizza del Perro Negro</a>'],
#      'photo_reference': 'CmRaAAAAAZ0OI6GSoSA8K3IWKecR0S2EtLD6H4myA7VK9vHKzbXu-1v8Rv4fIht3uWw1kQfA9qSfkCKWX0L1HFi1ISEPKS9RFIq3hPnz7dpf3Ymmc8FvNm4FVzfN6QTjUnB1N-mxEhC_Ahhptc2MEYB93CcjHXHiGhQEiuXBiHgB_rxrw_rlO8eUh5Fu0w',
#      'width': 1024}],
#    'place_id': 'ChIJS67Ey6x2Vo8RTiTblDl7VT0',
#    'plus_code': {'compound_code': 'X9XJ+7F Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+7F'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJS67Ey6x2Vo8RTiTblDl7VT0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1792,
#    'vicinity': 'Circuito Colonias 138, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 21.0006563, 'lng': -89.6152867},
#     'viewport': {'northeast': {'lat': 21.00202808029151,
#       'lng': -89.61404141970849},
#      'southwest': {'lat': 20.9993301197085, 'lng': -89.61673938029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '657620905f41cddeeefd73c87f0038e76d1320b9',
#    'name': 'Mr. Pampas',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112027953135784105871/photos">lebrak silva</a>'],
#      'photo_reference': 'CmRaAAAAou1lNbB4Vsek5rbJ3OuZfl_NUg3sD1ETKV6PtX3D_RYJdmCjHSEEwUWI4hTtHd0mCCip3ggbw5ML0yGTHHkiOdurCZ6t2CCx1GwWdKOjK8eKFtCVkPN08dBuw_g2lqLDEhDgIsFjpCvbqXAk3x7gyL6BGhTQMWPfw7tVGJSXGog2qdx68nU-GA',
#      'width': 1920}],
#    'place_id': 'ChIJE1CvhrJ2Vo8RF6OCmqVdXjU',
#    'plus_code': {'compound_code': '292M+7V Mérida, Yucatan, Mexico',
#     'global_code': '76HG292M+7V'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJE1CvhrJ2Vo8RF6OCmqVdXjU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3935,
#    'vicinity': '118 x, Prolongación paseo Montejo, Calle 27, México, Mérida'},
#   {'geometry': {'location': {'lat': 20.9987778, 'lng': -89.61446970000001},
#     'viewport': {'northeast': {'lat': 21.0000301302915,
#       'lng': -89.6131411697085},
#      'southwest': {'lat': 20.9973321697085, 'lng': -89.6158391302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd39c4485a4687e3717417c89a18cc8e6219ff525',
#    'name': 'A la pimienta',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107000429126721375259/photos">A la pimienta</a>'],
#      'photo_reference': 'CmRaAAAAUufW13PZhGJAXwILte46i5sKk_YUEsc0m9hkGIlDLAF0oY-AP7654i5sgaht9kc6exv4I6sb0fBNsvKrtsqMz8pXHJf3jhY2mzttXISK7yjU7yb0Ky85yGHbaQ1r8OZ2EhCsZNAeP3TRcm36W57Wb4euGhSY1LKMXnfG7GgI0b47MyYcr-hwnw',
#      'width': 1200}],
#    'place_id': 'ChIJ_7yIt7J2Vo8ROAqvR1B2Ivc',
#    'plus_code': {'compound_code': 'X9XP+G6 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XP+G6'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJ_7yIt7J2Vo8ROAqvR1B2Ivc',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 257,
#    'vicinity': 'Circuito Colonias 127, México, Mérida'},
#   {'geometry': {'location': {'lat': 20.9958321, 'lng': -89.6160525},
#     'viewport': {'northeast': {'lat': 20.9971913802915,
#       'lng': -89.61479411970849},
#      'southwest': {'lat': 20.9944934197085, 'lng': -89.6174920802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '7ace37da5f0e3d05373f8b7bfe11c29cd86105fb',
#    'name': 'Los Originales Tacos de Res',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101147416958233449587/photos">Kaa Ab S</a>'],
#      'photo_reference': 'CmRaAAAA0dV4XXXSBiC06Q6j3BfEVhQvbtzyShuWOGs_bbF5ifStF54-5qIuWlW3OUqXIzUJqKv7rZCcgWPsniihuPlbi_aVsMGaCtN1zKkEX2MPUsTCm-D56IoSMHJoEhglsjMxEhBlon6ltGpvr1y8tLBO-gSgGhR_eoVLPaedWA_wjz1HGE4fWEJ3-g',
#      'width': 1080}],
#    'place_id': 'ChIJScV8m1JxVo8RGtH_DNMAHcs',
#    'plus_code': {'compound_code': 'X9WM+8H Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WM+8H'},
#    'rating': 4.5,
#    'reference': 'ChIJScV8m1JxVo8RGtH_DNMAHcs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 35,
#    'vicinity': 'Itzimná, Mérida'},
#   {'geometry': {'location': {'lat': 21.001493, 'lng': -89.61488299999999},
#     'viewport': {'northeast': {'lat': 21.0027158802915,
#       'lng': -89.6135593697085},
#      'southwest': {'lat': 21.0000179197085, 'lng': -89.6162573302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '404c7db63b0a559ed74da23c3471f08e682e6b63',
#    'name': 'Osteria Piccoli',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 270,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103732674933667266467/photos">OSTERIA PICCOLI</a>'],
#      'photo_reference': 'CmRaAAAAK9ENF273oxNcdt27SF9SevZVIu6gBNGEZEXcLr3UDY8oBn5sE988iQ6BlfNPoDzk6WU4wMBQqLAG3Ki7k0q6aFaWc-ibS3o4xs3GcRpJ8HvmG3s1b2EbZvMluvhe1espEhDttknUmbeByt6bk4w3EGhQGhSojGbXTxfc2MbTHrJ9GIdFJXkPEw',
#      'width': 720}],
#    'place_id': 'ChIJ8cAMZLJ2Vo8RzqIacVgeGAU',
#    'plus_code': {'compound_code': '292P+H2 Mérida, Yucatan, Mexico',
#     'global_code': '76HG292P+H2'},
#    'price_level': 2,
#    'rating': 4.7,
#    'reference': 'ChIJ8cAMZLJ2Vo8RzqIacVgeGAU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 316,
#    'vicinity': 'Calle 30 112 Local 3 x 23 y 25 Yucatán MX, Mérida'},
#   {'geometry': {'location': {'lat': 20.9981762, 'lng': -89.6163722},
#     'viewport': {'northeast': {'lat': 20.9995988802915,
#       'lng': -89.6149274697085},
#      'southwest': {'lat': 20.9969009197085, 'lng': -89.61762543029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd4ca110e1db1e30fc089606d6b4587af9d7770b1',
#    'name': 'Burger King',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114053400770644356697/photos">el gallego heredia</a>'],
#      'photo_reference': 'CmRaAAAA3ueO_XV4nLSKawWMC3YaXyNmwo7URq6VGFG8O7iK5q_ukXcAVBjhX_YCg1fSs2PLYaP923OGoVopV0HpjZbhYqAudoHgy6j7BeKokcY7rXx9dSy9J0KqQdXL5bNztspYEhBymzTp_SC38KID8UcFy1LKGhRiOwWtTovQGuX-O7pkn4-1du4uZw',
#      'width': 4128}],
#    'place_id': 'ChIJY9x1Tq12Vo8RJcAtqpexutk',
#    'plus_code': {'compound_code': 'X9XM+7F Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XM+7F'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJY9x1Tq12Vo8RJcAtqpexutk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2382,
#    'vicinity': 'Calle 31 131, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.998244, 'lng': -89.615712},
#     'viewport': {'northeast': {'lat': 20.9995543302915,
#       'lng': -89.6143771197085},
#      'southwest': {'lat': 20.9968563697085, 'lng': -89.61707508029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '327304bb69f98c0f7feb2d06957ba82a5a3bff6f',
#    'name': "McCarthy's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105794800853062679353/photos">Laura Diaz</a>'],
#      'photo_reference': 'CmRaAAAAz4tT4BP6_W4RsNnSiVJkuN4n2nO1wTRVuhZEVLAmLRuYdyTPyp1m0wt-0ZrERXDUwmACKbitDA5bZU-b9glX-GaJEk5GG6cuX-KebZJGyCfosLtHuJ8burwYPxULLNV0EhCc-n-D56rcUAast6-OLIZgGhT32pI0u16oPfPWpB0hyT8w756P1w',
#      'width': 400}],
#    'place_id': 'ChIJAQMIqrJ2Vo8RyNB-NE2HXFw',
#    'plus_code': {'compound_code': 'X9XM+7P Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XM+7P'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJAQMIqrJ2Vo8RyNB-NE2HXFw',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3170,
#    'vicinity': 'Calle 30 #132 A x11A, Itzimná, Mérida'},
#   {'geometry': {'location': {'lat': 20.9982109, 'lng': -89.6179903},
#     'viewport': {'northeast': {'lat': 20.9995748802915,
#       'lng': -89.6165531697085},
#      'southwest': {'lat': 20.9968769197085, 'lng': -89.61925113029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4269562c43401dbbe9dfaec5e18cee175f945ee6',
#    'name': "Trotter's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1718,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106362701461480695113/photos">Arturo Gonzalez</a>'],
#      'photo_reference': 'CmRaAAAA3J_nEALkPYPiFUxeAFTX8I9601ACLmsYC2ek0ud1RTVpP2oaNWSBwC5m1qoy7bwHFzhblBCZA9EaHUpjnSlJCJnY9ak9TOdv1SUoOuaOSBQqG8Jn7iDx0DK_5XymTY9QEhDkd6-L0eDCn191elw2jTuWGhSBe-HI313f0CYvQ0XmWzLoRPgzQA',
#      'width': 2430}],
#    'place_id': 'ChIJgbGOKq12Vo8RqhK2SdKJzdQ',
#    'plus_code': {'compound_code': 'X9XJ+7R Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+7R'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJgbGOKq12Vo8RqhK2SdKJzdQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 659,
#    'vicinity': 'Calle 31 no.134, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9979932, 'lng': -89.6192654},
#     'viewport': {'northeast': {'lat': 20.99931013029151,
#       'lng': -89.6180513197085},
#      'southwest': {'lat': 20.9966121697085, 'lng': -89.6207492802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4252e57570fa180a1d3d09866a916ad39b4fe3af',
#    'name': 'Little Caesars Pizza',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2336,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100683313379316869131/photos">Alexander Escobar</a>'],
#      'photo_reference': 'CmRaAAAAFGvsOPBVKhk0f7PHD_QAQMlvKh1JiFjoUPcnVuQUhMpIb_VGD06cw_NwsH30_chnRmb9PJXx7R_D3sD_Fm9mx_22WdkW4xGfu3aKnwThYF9kMCsvU4JNfeEhU9Eritx5EhDrnPOckZ-_zhScIVTrQPbyGhTdSSYCZYDx7VR1Ysnd1WiqFZ_qIA',
#      'width': 4160}],
#    'place_id': 'ChIJF4Txyqx2Vo8RcCd1I-3_uDg',
#    'plus_code': {'compound_code': 'X9XJ+57 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+57'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJF4Txyqx2Vo8RcCd1I-3_uDg',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 462,
#    'vicinity': 'Calle 31 140, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9994186, 'lng': -89.61927899999999},
#     'viewport': {'northeast': {'lat': 21.0007238302915,
#       'lng': -89.6182016697085},
#      'southwest': {'lat': 20.9980258697085, 'lng': -89.6208996302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0619946d4bf8bf32d131946ea8a2daab4a1b5295',
#    'name': "Mago's Restaurante",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2192,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117079633809751029661/photos">Mago&#39;s Restaurante</a>'],
#      'photo_reference': 'CmRaAAAANV8u84nNu2V8keo4QWfNVNDJpQq5qQ0KFzClHU6E1AFlT5mejzj0T-giiG8QILr8qCiQO2HFPpvYoY7DBnyPn_p7glOwqLmh-Gxxd_b1w_Lu3mZWhNR3l7nfZcnkKvRsEhB-0b916Zygb57edtO_VfDZGhTayBKhAQXUNOGTy7p9nZlTa53vgw',
#      'width': 3386}],
#    'place_id': 'ChIJK3zxq3N3Vo8R2ggPcP6c71c',
#    'plus_code': {'compound_code': 'X9XJ+Q7 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XJ+Q7'},
#    'rating': 5,
#    'reference': 'ChIJK3zxq3N3Vo8R2ggPcP6c71c',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Calle 13 382, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9972041, 'lng': -89.61566289999999},
#     'viewport': {'northeast': {'lat': 20.9985708802915,
#       'lng': -89.61451686970848},
#      'southwest': {'lat': 20.9958729197085, 'lng': -89.6172148302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '33d1643c2c8b1e271092a0b8c43c39729d21c7f9',
#    'name': 'Wings Wagon',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111179093898473649398/photos">Edson Mota Rodríguez</a>'],
#      'photo_reference': 'CmRaAAAAkPVlSqq7EfWV-FMsmknOYQAjbEZ4JQ46pP_x-_oKeFRmj5B0trJXf-zppvx87zmCx-6LKwlGs3h48U2ms5UCaSzJwZ-SSP2oo8pPpPfLZ2Bx03GnFEvmQTdmHIpGjblQEhAaf1sd_QEQz4ptaeEmXkoWGhRDfBLyKgQgapUmMlr00Co42J_LeQ',
#      'width': 3264}],
#    'place_id': 'ChIJe2eMV01xVo8RrEnoQoPqBq0',
#    'plus_code': {'compound_code': 'X9WM+VP Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WM+VP'},
#    'reference': 'ChIJe2eMV01xVo8RrEnoQoPqBq0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '97100, Prolongación Paseo Montejo 446, Itzimná, Mérida'},
#   {'geometry': {'location': {'lat': 20.9982613, 'lng': -89.6200873},
#     'viewport': {'northeast': {'lat': 20.9995978302915,
#       'lng': -89.61873581970849},
#      'southwest': {'lat': 20.9968998697085, 'lng': -89.6214337802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '7392d474b8ef22db9a4e6e9f033b159cea9d9c3f',
#    'name': 'Tacos Doña Chona',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 746,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101247493105307510885/photos">Andrés Covarrubias Lopez</a>'],
#      'photo_reference': 'CmRaAAAAd9ZQfZMOrW0eRAGWI0oneIIQrFbClpgk37ZALxUsjDYG6GnxHO4eJZhqORBXNwOcbZcgIa-rcD2uOvdymMaSMU59FBqKY4fWM-IABQq8WEvXuWWf20p8yHvxI490k7QsEhA62CKiDFHkTUjbW3Tz6D_YGhQwnVB_h9JJMCjlR11Vxj3sNezIvw',
#      'width': 891}],
#    'place_id': 'ChIJfSFOZBl3Vo8RMKSzmbuK8-0',
#    'plus_code': {'compound_code': 'X9XH+8X Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XH+8X'},
#    'reference': 'ChIJfSFOZBl3Vo8RMKSzmbuK8-0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 31 #145 local A x 38 y 40, Circuito Colonias, Mérida'},
#   {'geometry': {'location': {'lat': 20.9965909, 'lng': -89.6191297},
#     'viewport': {'northeast': {'lat': 20.9979177802915,
#       'lng': -89.61777641970849},
#      'southwest': {'lat': 20.9952198197085, 'lng': -89.62047438029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0ea0e0655ca31e424c941fa4014d96705dbce6ec',
#    'name': 'Cocina Esquinita Buenavista',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJIdADAztxVo8RnW7LfxOznss',
#    'plus_code': {'compound_code': 'X9WJ+J8 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WJ+J8'},
#    'rating': 4.4,
#    'reference': 'ChIJIdADAztxVo8RnW7LfxOznss',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.9991956, 'lng': -89.6149174},
#     'viewport': {'northeast': {'lat': 21.0005470802915,
#       'lng': -89.61358276970849},
#      'southwest': {'lat': 20.9978491197085, 'lng': -89.61628073029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2bed98f856aec527669089ee6697abca285398e4',
#    'name': 'Taqueria Los Tortuguitas',
#    'place_id': 'ChIJd08xvLJ2Vo8RiZjcLRcE3pg',
#    'plus_code': {'compound_code': 'X9XP+M2 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9XP+M2'},
#    'reference': 'ChIJd08xvLJ2Vo8RiZjcLRcE3pg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 28, México, Mérida'},
#   {'geometry': {'location': {'lat': 20.996483, 'lng': -89.61976589999999},
#     'viewport': {'northeast': {'lat': 20.9978100802915,
#       'lng': -89.6184126197085},
#      'southwest': {'lat': 20.99511211970849, 'lng': -89.6211105802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3a57e23155c8ae5d0ba8229529f7f50a2650dd57',
#    'name': 'Tortas & Sopes El Fracc',
#    'place_id': 'ChIJzYeaQlNxVo8RzW0DmBAjhz4',
#    'plus_code': {'compound_code': 'X9WJ+H3 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WJ+H3'},
#    'reference': 'ChIJzYeaQlNxVo8RzW0DmBAjhz4',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle 13, Buenavista, Mérida'},
#   {'geometry': {'location': {'lat': 20.995689, 'lng': -89.61751319999999},
#     'viewport': {'northeast': {'lat': 20.9969911802915,
#       'lng': -89.61615716970849},
#      'southwest': {'lat': 20.9942932197085, 'lng': -89.6188551302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'dbe2166c547ca4710b4159e1e79c568b93d2fa43',
#    'name': 'Zhen Liying',
#    'place_id': 'ChIJq6qq-lJxVo8RaQ2CCowNCUk',
#    'rating': 3.5,
#    'reference': 'ChIJq6qq-lJxVo8RaQ2CCowNCUk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Gran Plaza Local 93, Fraccionamiento Montejo, Mérida'},
#   {'geometry': {'location': {'lat': 20.9962535, 'lng': -89.6197918},
#     'viewport': {'northeast': {'lat': 20.9975758302915,
#       'lng': -89.6184911197085},
#      'southwest': {'lat': 20.9948778697085, 'lng': -89.6211890802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2c783fae4037137abb9365b11fe3d4f75d3dbd90',
#    'name': '"POLLOS DEL RANCHO AL CARBÓN"',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJC8CFaFNxVo8RshLPPtSkCOs',
#    'plus_code': {'compound_code': 'X9WJ+G3 Mérida, Yucatan, Mexico',
#     'global_code': '76GGX9WJ+G3'},
#    'rating': 4.3,
#    'reference': 'ChIJC8CFaFNxVo8RshLPPtSkCOs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Calle 58ᶜ 470, Buenavista'},
#   {'geometry': {'location': {'lat': 21.00159, 'lng': -89.6161159},
#     'viewport': {'northeast': {'lat': 21.0028702802915,
#       'lng': -89.6147807697085},
#      'southwest': {'lat': 21.00017231970849, 'lng': -89.61747873029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '11143792cffa2f8508083624d0f1c93913f98cb3',
#    'name': 'RIEH',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106210211641146191508/photos">Nicolas Navarrete</a>'],
#      'photo_reference': 'CmRaAAAACYqK3tys4qZ_Zn9oYWqD8EqPapd_YpfP078NRdyBXDPfTkeqP5uhYNU8l_xfueXXX7xphbXj1OpJCmkf8QCNvl0rU04gdzgyAsUNFR3FPSxwds32SullyvklxN3zQ8YLEhCPacZYRF06fh88pXo1O4bCGhQRFtWc-K3M-n20QDD_8DPPrSYETQ',
#      'width': 4032}],
#    'place_id': 'ChIJe9SSha12Vo8R4duZuE3Cc5c',
#    'plus_code': {'compound_code': '292M+JH Mérida, Yucatan, Mexico',
#     'global_code': '76HG292M+JH'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJe9SSha12Vo8R4duZuE3Cc5c',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 97,
#    'vicinity': 'Calle 25 131, Buenavista, Mérida'}],
#  'status': 'OK'}

# %%
#Creating a data frame from trompos_circuito['results']
table_similar_places = pd.DataFrame(trompos_circuito_google['results'])

#Teacher, again the google library didn't take my rankby (idk if Ii was doing it wrong, probably yes), but I did it manualy
table_similar_places = table_similar_places.sort_values('rating',ascending=False).reset_index(drop=False)

#Selecting only the desired columns
table_similar_places = table_similar_places[['id', 'name', 'rating', 'user_ratings_total']]

#Renaming the columns to  Place Name, Place Id, Rating, Total of User Ratings.
table_similar_places = table_similar_places.rename(columns={"id": "Place id", "name": "Place Name", "rating" : "Rating", "user_ratings_total" : "Total of User Ratings"})

#Reordering the columns
table_similar_places = table_similar_places[["Place Name", "Place id", "Rating", "Total of User Ratings"]]

table_similar_places
# Out:
#                        Place Name                                  Place id  \
# 0              Mago's Restaurante  0619946d4bf8bf32d131946ea8a2daab4a1b5295
# 1                 Osteria Piccoli  404c7db63b0a559ed74da23c3471f08e682e6b63
# 2                      Mr. Pampas  657620905f41cddeeefd73c87f0038e76d1320b9
# 3                       Trotter's  4269562c43401dbbe9dfaec5e18cee175f945ee6
# 4                     Los Trompos  cf6c67c9eb44c578189fe7afa775b9c87026672f
# 5                   A la pimienta  d39c4485a4687e3717417c89a18cc8e6219ff525
# 6     Los Originales Tacos de Res  7ace37da5f0e3d05373f8b7bfe11c29cd86105fb
# 7                      McCarthy's  327304bb69f98c0f7feb2d06957ba82a5a3bff6f
# 8                            RIEH  11143792cffa2f8508083624d0f1c93913f98cb3
# 9           Pizza del Perro Negro  3da77355187a5c061f10675393003c55e6d23bad
# 10    Cocina Esquinita Buenavista  0ea0e0655ca31e424c941fa4014d96705dbce6ec
# 11  "POLLOS DEL RANCHO AL CARBÓN"  2c783fae4037137abb9365b11fe3d4f75d3dbd90
# 12                Mi Viejo Molino  0525209b56b3dfac93492825024c73986cb1c704
# 13                    Burger King  d4ca110e1db1e30fc089606d6b4587af9d7770b1
# 14           Little Caesars Pizza  4252e57570fa180a1d3d09866a916ad39b4fe3af
# 15                    Zhen Liying  dbe2166c547ca4710b4159e1e79c568b93d2fa43
# 16                    Wings Wagon  33d1643c2c8b1e271092a0b8c43c39729d21c7f9
# 17               Tacos Doña Chona  7392d474b8ef22db9a4e6e9f033b159cea9d9c3f
# 18       Taqueria Los Tortuguitas  2bed98f856aec527669089ee6697abca285398e4
# 19        Tortas & Sopes El Fracc  3a57e23155c8ae5d0ba8229529f7f50a2650dd57
#
#     Rating  Total of User Ratings
# 0      5.0                    2.0
# 1      4.7                  316.0
# 2      4.6                 3935.0
# 3      4.6                  659.0
# 4      4.5                 3130.0
# 5      4.5                  257.0
# 6      4.5                   35.0
# 7      4.5                 3170.0
# 8      4.5                   97.0
# 9      4.4                 1792.0
# 10     4.4                   10.0
# 11     4.3                    3.0
# 12     4.2                 1391.0
# 13     4.1                 2382.0
# 14     4.1                  462.0
# 15     3.5                    4.0
# 16     NaN                    NaN
# 17     NaN                    NaN
# 18     NaN                    NaN
# 19     NaN                    NaN

# %% [markdown]
# G. Create a Github Project as a Tutorial about How to Use the Google API. Don't forget to include a section with the set of instructions to obtain the Google API Key. In this tutorial, compare the use of the Google Maps [Places API] (https://developers.google.com/places/web-service/intro) and the Python [GoogleMaps](https://github.com/googlemaps/google-maps-services-python) Library using this activity tasks as examples.

# %% [markdown]
# https://github.com/alexacanche/How-to-Use-the-Google-API

# %% [markdown]
# ## Checklist
#
# | Task | Points |
# |:----:|:------:|
# |   Class Participation  |   10   |
# |   a  |   10   |
# |   b  |   10   |
# |   c  |   10   |
# |   d  |   10   |
# |   e  |   10   |
# |   f  |   20   |
# |   g  |   20   |
#
#
# * **Important!** Partial credit can be obteined in each task.
# * Don not forget to document your functions! [Here](http://google.github.io/styleguide/pyguide.html) is the Python Programming Styleguide from Google. [Section 3.8](http://google.github.io/styleguide/pyguide.html#38-comments-and-docstrings) is about Comments and Docstrings.
# * To obtain the Class Participation Score you must complete an early submission with tasks: A, B and C.
